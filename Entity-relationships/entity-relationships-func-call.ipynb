# %% [markdown]
# Revenging open ai to extract the relationships between the node entities for each article

# %%
import os
import certifi
from pymongo import MongoClient
from pymongo.server_api import ServerApi
from dotenv import load_dotenv

# Load environment variables from .env file
load_dotenv()

# Get MongoDB credentials from environment variables
MONGO_URI = os.getenv("MONGO_URI")
DB_NAME = os.getenv("MONGO_DB_NAME")
ARTICLES_COLLECTION_NAME = os.getenv("MONGO_ARTICLES_NAME")
NODES_COLLECTION_NAME = os.getenv("MONGO_NODES_NAME")

# Ensure all necessary environment variables are set
if not all([MONGO_URI, DB_NAME, ARTICLES_COLLECTION_NAME, NODES_COLLECTION_NAME]):
    print("❌ Missing required environment variables. Check your .env file.")
    exit()

# Create MongoDB client with TLS verification
try:
    client = MongoClient(MONGO_URI, server_api=ServerApi('1'), tlsCAFile=certifi.where())
    db = client[DB_NAME]

    # Define collections
    articles_collection = db[ARTICLES_COLLECTION_NAME]  # Stores articles
    nodes_collection = db[NODES_COLLECTION_NAME]  # Stores extracted nodes

    # Verify connection
    client.admin.command('ping')
    print(f"✅ Connected to MongoDB Atlas! Database: {DB_NAME}")

except Exception as e:
    print(f"❌ MongoDB Connection Error: {e}")
    exit()
# Out:
# ✅ Connected to MongoDB Atlas! Database: tuone

# %%
#articles_collection.find_one()

# %%
from openai import OpenAI
import os
from dotenv import load_dotenv
load_dotenv()
openAI_api_key = os.getenv('OPENAI_API_KEY')
client = OpenAI(api_key=openAI_api_key)

def ping_openai(client):
    try:
        response = client.models.list()
        print("✅ Successfully connected to OpenAI API!")
        print(f"Available Models: {[model.id for model in response.data]}")
    except Exception as e:
        print(f"❌ OpenAI API Connection Error: {e}")
ping_openai(client)
# Out:
# ✅ Successfully connected to OpenAI API!
# Available Models: ['gpt-4o-mini-transcribe', 'gpt-4o-audio-preview-2024-12-17', 'dall-e-3', 'dall-e-2', 'gpt-4o-audio-preview-2024-10-01', 'omni-moderation-latest', 'omni-moderation-2024-09-26', 'gpt-4o-realtime-preview-2024-10-01', 'babbage-002', 'tts-1-hd-1106', 'text-embedding-3-large', 'gpt-4', 'gpt-4o-mini-2024-07-18', 'o3-mini', 'gpt-4o-2024-05-13', 'gpt-4o-realtime-preview-2024-12-17', 'tts-1-hd', 'gpt-4o-mini-audio-preview', 'o3-mini-2025-01-31', 'gpt-4o-audio-preview', 'o1-preview-2024-09-12', 'gpt-4o-realtime-preview', 'gpt-3.5-turbo-instruct-0914', 'gpt-4o-mini-search-preview', 'tts-1-1106', 'davinci-002', 'gpt-3.5-turbo-1106', 'gpt-4o-search-preview', 'gpt-4-turbo', 'gpt-3.5-turbo-instruct', 'gpt-3.5-turbo', 'gpt-4-turbo-preview', 'gpt-4o-mini-search-preview-2025-03-11', 'gpt-4o-mini-realtime-preview', 'chatgpt-4o-latest', 'whisper-1', 'gpt-3.5-turbo-0125', 'gpt-4-turbo-2024-04-09', 'gpt-3.5-turbo-16k', 'gpt-4o', 'gpt-4o-mini-realtime-preview-2024-12-17', 'gpt-4-1106-preview', 'text-embedding-ada-002', 'o1-preview', 'gpt-4-0613', 'gpt-4.5-preview', 'gpt-4.5-preview-2025-02-27', 'gpt-4o-search-preview-2025-03-11', 'computer-use-preview', 'gpt-4o-2024-11-20', 'tts-1', 'gpt-4o-mini-tts', 'text-embedding-3-small', 'gpt-4-0125-preview', 'o1-pro-2025-03-19', 'computer-use-preview-2025-03-11', 'gpt-4o-transcribe', 'gpt-4o-mini', 'o1-2024-12-17', 'o1', 'o1-pro', 'gpt-4o-2024-08-06', 'o1-mini', 'gpt-4o-mini-audio-preview-2024-12-17', 'o1-mini-2024-09-12', 'ft:gpt-4o-mini-2024-07-18:personal:num-expansions:AIZ2bvuF:ckpt-step-105', 'ft:gpt-4o-mini-2024-07-18:personal:num-expansions:AIZ2bAk5:ckpt-step-210', 'ft:gpt-4o-mini-2024-07-18:personal:num-expansions:AIZ2cenS', 'ft:gpt-4o-mini-2024-07-18:personal:num-expansions:AJJ93fdU:ckpt-step-199', 'ft:gpt-4o-mini-2024-07-18:personal:num-expansions:AJJ94LFl:ckpt-step-398', 'ft:gpt-4o-mini-2024-07-18:personal:num-expansions:AJJ94E5b', 'ft:gpt-4o-mini-2024-07-18:personal:return-value:AJK83NIU:ckpt-step-156', 'ft:gpt-4o-mini-2024-07-18:personal:return-value:AJK84Fpr:ckpt-step-312', 'ft:gpt-4o-mini-2024-07-18:personal:return-value:AJK84Gbm', 'ft:gpt-4o-mini-2024-07-18:personal:return-status:AJKjXMoW:ckpt-step-306', 'ft:gpt-4o-mini-2024-07-18:personal:return-value:AJKGXPYy:ckpt-step-156', 'ft:gpt-4o-mini-2024-07-18:personal:return-value:AJKGXpcf:ckpt-step-312', 'ft:gpt-4o-mini-2024-07-18:personal:return-value:AJKGYiKy', 'ft:gpt-4o-mini-2024-07-18:personal:multiple-return-values:AJKRAcHz:ckpt-step-59', 'ft:gpt-4o-mini-2024-07-18:personal:multiple-return-values:AJKRAIqI:ckpt-step-118', 'ft:gpt-4o-mini-2024-07-18:personal:multiple-return-values:AJKRBH3e', 'ft:gpt-4o-mini-2024-07-18:personal:return-status:AJKjXH5c:ckpt-step-153', 'ft:gpt-4o-mini-2024-07-18:personal:return-status:AJKjY2fz', 'ft:gpt-4o-mini-2024-07-18:personal:multiple-return-statuses:AJKvacdp:ckpt-step-70', 'ft:gpt-4o-mini-2024-07-18:personal:multiple-return-statuses:AJKvalFM:ckpt-step-140', 'ft:gpt-4o-mini-2024-07-18:personal:multiple-return-statuses:AJKvbgjo', 'ft:gpt-4o-mini-2024-07-18:personal:return-capacity:AJLE7wll:ckpt-step-156', 'ft:gpt-4o-mini-2024-07-18:personal:return-capacity:AJLE8Gw4:ckpt-step-312', 'ft:gpt-4o-mini-2024-07-18:personal:return-capacity:AJLE8MZB', 'ft:gpt-4o-mini-2024-07-18:personal:multiple-return-capacities:AJLPWJ1U:ckpt-step-53', 'ft:gpt-4o-mini-2024-07-18:personal:multiple-return-capacities:AJLPWHpE:ckpt-step-106', 'ft:gpt-4o-mini-2024-07-18:personal:multiple-return-capacities:AJLPXkDZ', 'ft:gpt-4o-mini-2024-07-18:personal:return-dt-announce:AJMziNNI', 'ft:gpt-4o-mini-2024-07-18:personal:return-dt-announce:AJMzhWQy:ckpt-step-172', 'ft:gpt-4o-mini-2024-07-18:personal:return-dt-announce:AJMziJO4:ckpt-step-344', 'ft:gpt-4o-mini-2024-07-18:personal:multiple-return-dt-announce:AJNCvZes:ckpt-step-78', 'ft:gpt-4o-mini-2024-07-18:personal:multiple-return-dt-announce:AJNCwvhr:ckpt-step-156', 'ft:gpt-4o-mini-2024-07-18:personal:multiple-return-dt-announce:AJNCwI4G', 'ft:gpt-4o-mini-2024-07-18:personal:re ...

# %%
import json
from bson import json_util
def fetch_articles(limit=00,offset=0):
    try:
        # Fetch articles with an optional limit
        articles_cursor = (articles_collection.find()
                           .skip(offset)
                           .limit(limit))
        articles = list(articles_cursor)

        if articles:
            print(f"✅ Retrieved {len(articles)} articles from MongoDB.\n")
            for idx, article in enumerate(articles, start=1):
                print(f"--- Article {idx} ---")
                # Convert BSON to JSON using json_util
                article_json = json.dumps(article, indent=4, default=json_util.default)
                print(article_json)
        else:
            print("⚠️ No articles found in the collection.")

        return articles

    except Exception as e:
        print(f"❌ Error fetching articles: {e}")
        return []


# Fetch and print articles in JSON format
articles = fetch_articles(limit=5,offset=15)
# Out:
# ✅ Retrieved 5 articles from MongoDB.
#
# --- Article 1 ---
# {
#     "_id": {
#         "$oid": "67b1e4240554959fd725ee05"
#     },
#     "title": "BASF and TODA reinforce battery production in Japan and USA",
#     "paragraphs": [
#         {
#             "p1": "BASF and TODA strengthen their cooperation as they announce to create the world\u2019s largest calcination facility for high nickel Cathode Active Materials in Japan. They will also combine their manufacturing activities in the States.",
#             "p2": "BASF TODA Battery Materials LLC (BTBM), a joint venture between BASF and TODA, has now tripled its high nickel Cathode Active Materials (CAMs) capacity at its Onoda site in Japan.",
#             "p3": "Jeffrey Lou, Senior Vice President of Battery Materials at BASF said that with the expansion \u201cBASF (is) further strengthening our market position in high energy cathode active materials for e-mobility applications.\u201d",
#             "p4": "A similar move is planned in the States were both companies announced they will combine their production facilities in Elyria, Ohio, and Battle Creek, Michigan to form BASF Toda America LLC (BTA). Again it is the growing market for e-mobility driving the alliance."
#         }
#     ],
#     "meta": {
#         "ID": "1100049",
#         "date": "16-12-2017",
#         "url": "https://www.electrive.com/2017/12/16/basf-toda-reinforce-battery-production-japan-usa/"
#     },
#     "combined_text": "BASF and TODA strengthen their cooperation as they announce to create the world\u2019s largest calcination facility for high nickel Cathode Active Materials in Japan. They will also combine their manufacturing activities in the States. BASF TODA Battery Materials LLC (BTBM), a joint venture between BASF and TODA, has now tripled its high nickel Cathode Active Materials (CAMs) capacity at its Onoda site in Japan. Jeffrey Lou, Senior Vice President of Battery Materials at BASF said that with the expansion \u201cBASF (is) further strengthening our market position in high energy cathode active materials for e-mobility applications.\u201d A similar move is planned in the States were both companies announced they will combine their production facilities in Elyria, Ohio, and Battle Creek, Michigan to form BASF Toda America LLC (BTA). Again it is the growing market for e-mobility driving the alliance.",
#     "nodes": [
#         {
#             "article_id": "67b1e4240554959fd725ee05",
#             "id": "basf",
#             "type": "company",
#             "name": "BASF",
#             "parent_company": null,
#             "subsidiaries": [],
#             "location": {
#                 "city": "",
#                 "country": ""
#             },
#             "products": []
#         },
#         {
#             "article_id": "67b1e4240554959fd725ee05",
#             "id": "toda",
#             "type": "company",
#             "name": "TODA",
#             "parent_company": null,
#             "subsidiaries": [],
#             "location": {
#                 "city": "",
#                 "country": ""
#             },
#             "products": []
#         },
#         {
#             "article_id": "67b1e4240554959fd725ee05",
#             "id": "basf_toda_jv",
#             "type": "joint_venture",
#             "name": "BASF TODA Battery Materials LLC",
#             "parent_company": null,
#             "subsidiaries": [],
#             "location": {
#                 "city": "",
#                 "country": ""
#             },
#             "products": []
#         },
#         {
#             "article_id": "67b1e4240554959fd725ee05",
#             "id": "factory_onoda",
#             "type": "factory",
#             "name": "BASF TODA Calcination Facility",
#             "parent_company": null,
#             "subsidiaries": [],
#             "location": {
#                 "city": "Onoda",
#                 "country": "Japan"
#             },
#             "products": [
#                 "high nickel Cathode Active Materials"
#             ]
#         },
#         {
#             "article_id": "67b1e4240554959fd725ee05",
#             "id": "factory_elyria",
#             "type": "factory",
#             "name": "BASF Toda America LLC",
#             "parent_company": null,
#             "subsidiaries": [],
#             "location": {
#                 "city": "Elyria",
#                 "country": "United States"
#             },
#             "products": [
#                 "e-mobility components"
#             ]
#         },
#         {
#             "article_id": "67b1e4240554959fd725ee05",
#             "id": "factory_battle_creek",
#             "type": "factory",
#             "name": "BASF Toda America LLC",
#             "parent_company": null,
#             "subsidiaries": [],
#             "location": {
#                 "city": "Battle Creek",
#                 "country": "United States"
#             },
#             "products": [
#                 "e-mobility components"
#             ]
#         }
#     ]
# }
# --- Article 2 ---
# {
#     "_id": {
#         "$oid": "67b1e4250554959fd725ee06"
#     },
#     "title": "Daimler motor factory to turn into battery centre in Germany",
#     "paragraphs": [
#         {
#             "p1": "Workers in Untert\u00fcrkheim rejoice as Daimler announces to join its battery research with the facilities of its subsidiary Accumotive on site. Together the location will host what Daimler calls its competence centre for batteries within the larger push for e-mobility production hubs.",
#             "p2": "Daimler had started the discussion to \u201cinsource\u201d the Accumotive unitpreviouslyand has now confirmed the step. The aim is to bundle all battery competencies in Untert\u00fcrkheim. Accumotive\u2019s 300 employees will now officially work for Daimler and get paid the actual tariff thanks to the workers council.",
#             "p3": "Overall, this is a strengthening of Daimler\u2019s German production hubs.Already last summer, Daimler\u2019s management and the workers council struggled intensely about Untert\u00fcrkheim becoming home to Mercedes\u2019 fourth battery production as well as a hotspot for electric drives and components with more than 250 jobs to be generated. This has now become a reality.",
#             "p4": "Apart from batteries, the related agreement included assemblage of powertrain modules for EVs of the EQ brand and the creation of a \u201cproject house eATS\u201d in order to gain additional know-how for the next electric drive systems.",
#             "p5": "This latest move comes only days after Daimler hasbroken ground for a new facilityin German Sindelfingen, where it will build the upcoming EQ models. Untert\u00fcrkheim is part of that same network of global production hubs Daimler is currently setting up as it pushes to make it into the electric era.",
#             "p6": "Apart from Sindelfingen and Untert\u00fcrkheim, there are plants in German Rastatt as well as Tuscaloosa in the USA.\u00a0China is on board too through BBAC, Daimler\u2019s joint venture with BAIC in China. Last summer, Daimler also announced plans to build up local battery assembly with BAIC (wereported) which will then deliver the battery packs for the first EQ.",
#             "p7": "Daimler will also complete a second battery factory in Kamenz this year as preparations for the EQC at the Mercedes-Benz plant in Bremen intensify asplanned."
#         }
#     ],
#     "meta": {
#         "ID": "1100052",
#         "date": "25-02-2018",
#         "url": "https://www.electrive.com/2018/02/25/daimler-motor-factory-turn-battery-centre-germany/"
#     },
#     "combined_text": "Workers in Untert\u00fcrkheim rejoice as Daimler announces to join its battery research with the facilities of its subsidiary Accumotive on site. Together the location will host what Daimler calls its competence centre for batteries within the larger push for e-mobility production hubs. Daimler had started the discussion to \u201cinsource\u201d the Accumotive unitpreviouslyand has now confirmed the step. The aim is to bundle all battery competencies in Untert\u00fcrkheim. Accumotive\u2019s 300 employees will now officially work for Daimler and get paid the actual tariff thanks to the workers council. Overall, this is a strengthening of Daimler\u2019s German production hubs.Already last summer, Daimler\u2019s management and the workers council struggled intensely about Untert\u00fcrkheim becoming home to Mercedes\u2019 fourth battery production as well as a hotspot for electric drives and components with more than 250 jobs to be generated. This has now become a reality. Apart from batteries, the related agreement included assemblage of powertrain modules for EVs of the EQ brand and the creation of a \u201cproject house eATS\u201d in order to gain additional know-how for the next electric drive systems. This latest move comes only days after Daimler hasbroken ground for a new facilityin German Sindelfingen, where it will build the upcoming EQ models. Untert\u00fcrkheim is part of that same network of global production hubs Daimler is currently setting up as it pushes to make it into the electric era. Apart from Sindelfingen and Untert\u00fcrkheim, there are plants in German Rastatt as well as Tuscaloosa in the USA.\u00a0China is on board too through BBAC, Daimler\u2019s joint venture with BAIC in China. Last summer, Daimler also announced plans to build up local battery assembly with BAIC (wereported) which will then deliver the battery packs for the first EQ. Daimler will also complete a second battery factory in Kamenz this year as preparations for the EQC at the Mercedes-Benz plant in Bremen intensify asplanned.",
#     "nodes": [
#         {
#             "article_id": "67b1e4250554959fd725ee06",
#             "id": "daimler",
#             "type": "company",
#             "name": "Daimler",
#             "parent_company": null,
#             "subsidiaries": [
#                 "accumotive"
#             ],
#             "location": {
#                 "city": "",
#                 "country": ""
#             },
#             "products": []
#         },
#         {
#             "article_id": "67b1e4250554959fd725ee06",
#             "id": "accumotive",
#             "type": "company",
#             "name": "Accumotive",
#             "parent_company": "Daimler",
#             "subsidiaries": [],
#             "location": {
#                 "city": "",
#                 "country": ""
#             },
#             "products": []
#         },
#         {
#             "article_id": "67b1e4250554959fd725ee06",
#             "id": "bbac",
#             "type": "joint_venture",
#             "name": "BBAC",
#             "parent_company": null,
#             "subsidiaries": [],
#             "location": {
#                 "city": "",
#                 "country": ""
#             },
#             "products": []
#         },
#         {
#             "article_id": "67b1e4250554959fd725ee06",
#             "id": "factory_untertuerkheim",
#             "type": "factory",
#             "name": "Daimler Battery Competence Centre",
#             "parent_company": null,
#             "subsidiaries": [],
#             "location": {
#                 "city": "Untert\u00fcrkheim",
#                 "country": "Germany"
#             },
#             "products": [
#                 "batteries",
#                 "powertrain modules for EVs"
#             ]
#         },
#         {
#             "article_id": "67b1e4250554959fd725ee06",
#             "id": "factory_sindelfingen",
#             "type": "factory",
#             "name": "Daimler Sindelfingen Facility",
#             "parent_company": null,
#             "subsidiaries": [],
#             "location": {
#                 "city": "Sindelfingen",
#                 "country": "Germany"
#             },
#             "products": [
#                 "EQ models"
#             ]
#         },
#         {
#             "article_id": "67b1e4250554959fd725ee06",
#             "id": "factory_rastatt",
#             "type": "factory",
#             "name": "Daimler Rastatt Plant",
#             "parent_company": null,
#             "subsidiaries": [],
#             "location": {
#                 "city": "Rastatt",
#                 "country": "Germany"
#             },
#             "products": [
#                 "electric drives and components"
#             ]
#         },
#         {
#             "article_id": "67b1e4250554959fd725ee06",
#             "id": "factory_tuscaloosa",
#             "type": "factory",
#             "name": "Daimler Tuscaloosa Plant",
#             "parent_company": null,
#             "subsidiaries": [],
#             "location": {
#                 "city": "Tuscaloosa",
#                 "country": "USA"
#             },
#             "products": [
#                 "electric vehicles"
#             ]
#         },
#         {
#             "article_id": "67b1e4250554959fd725ee06",
#             "id": "factory_kamenz",
#             "type": "factory",
#             "name": "Daimler Kamenz Battery Factory",
#             "parent_company": null,
#             "subsidiaries": [],
#             "location": {
#                 "city": "Kamenz",
#                 "country": "Germany"
#             },
#             "products": [
#                 "batteries"
#             ]
#         },
#         {
#             "article_id": "67b1e4250554959fd725ee06",
#             "id": "factory_bremen",
#             "type": "factory",
#             "name": "Mercedes-Benz Bremen Plant",
#             "parent_company": null,
#             "subsidiaries": [],
#             "location": {
#                 "city": "Bremen",
#                 "country": "Germany"
#             },
#             "products": [
#                 "EQC"
#             ]
#         }
#     ]
# }
# --- Article 3 ---
# {
#     "_id": {
#         "$oid": "67b1e4250554959fd725ee07"
#     },
#     "title": "Tennet uses 100 Tesla car batteries as buffer",
#     "paragraphs": [
#         {
#             "p1": "Dutch grid operator Tennet relies on batteries from 100 Tesla cars to stabilise its grid,bizz energyhas learnt. The company determines how fast or slow batteries of these vehicles get charged.",
#             "p2": "In return, Tennet pays unspecified fees to the owners. The pilot project runs until summer, also Dutch eco-electricity company Vandebron is involved.bizzenergytoday.com(in German)"
#         }
#     ],
#     "meta": {
#         "ID": "1100059",
#         "date": "26-01-2018",
#         "url": "https://www.electrive.com/2018/01/26/tennet-uses-100-tesla-car-batteries-buffer/"
#     },
#     "combined_text": "Dutch grid operator Tennet relies on batteries from 100 Tesla cars to stabilise its grid,bizz energyhas learnt. The company determines how fast or slow batteries of these vehicles get charged. In return, Tennet pays unspecified fees to the owners. The pilot project runs until summer, also Dutch eco-electricity company Vandebron is involved.bizzenergytoday.com(in German)",
#     "nodes": [
#         {
#             "article_id": "67b1e4250554959fd725ee07",
#             "id": "tennet",
#             "type": "company",
#             "name": "Tennet",
#             "parent_company": null,
#             "subsidiaries": [],
#             "location": {
#                 "city": "",
#                 "country": ""
#             },
#             "products": []
#         },
#         {
#             "article_id": "67b1e4250554959fd725ee07",
#             "id": "tesla",
#             "type": "company",
#             "name": "Tesla",
#             "parent_company": null,
#             "subsidiaries": [],
#             "location": {
#                 "city": "",
#                 "country": ""
#             },
#             "products": []
#         },
#         {
#             "article_id": "67b1e4250554959fd725ee07",
#             "id": "vandebron",
#             "type": "company",
#             "name": "Vandebron",
#             "parent_company": null,
#             "subsidiaries": [],
#             "location": {
#                 "city": "",
#                 "country": ""
#             },
#             "products": []
#         }
#     ]
# }
# --- Article 4 ---
# {
#     "_id": {
#         "$oid": "67b1e4260554959fd725ee08"
#     },
#     "title": "Siemens may start producing batteries in Goerlitz",
#     "paragraphs": [
#         {
#             "p1": "As the turbine factory in Goerlitz, Germany, is winding down, Siemens has had to face much criticism. The prospective loss of jobs and unavoidable layoffs have been difficult for both political relations as well as the concerned employees. A new battery factory in Oberlausitz may offer relief.",
#             "p2": "However, reports indicate Siemens CEO Jae Kaeser has commented he is planning to meet the challenge head on, and to save and consolidate the production area with the industry concept Oberlausitz. The concept will be designed to meet the ongoing challenge of saving 3,500 jobs, as well as the closure of factories in G\u00f6rlitz, Erfurt, Leipzig and Offenbach.",
#             "p3": "As the coal mining facilities are closing and winding down, a new economic concept will be needed to keep the region at work, as many jobs are dependent on the industry present in the areas. A step towards renewable energy production will prove to be more long-lived and will provide the region with new significance. The move is planned to take place in the next 2-5 years. This would include large scale infrastructural changes as well as the construction of a new industry park.",
#             "p4": "Whether they will receive subsidies for the plans is not yet clear, however the existing expertise and partnerships maintained by Siemens is certainly sufficient to transform the region. It would also heavily expand Germany\u2019s industrial capabilities regarding environmentally friendly technologies and breathe new life into the region.",
#             "p5": "faz.net(in German)"
#         }
#     ],
#     "meta": {
#         "ID": "1100060",
#         "date": "01-02-2018",
#         "url": "https://www.electrive.com/2018/02/01/siemens-may-start-producing-batteries-goerlitz/"
#     },
#     "combined_text": "As the turbine factory in Goerlitz, Germany, is winding down, Siemens has had to face much criticism. The prospective loss of jobs and unavoidable layoffs have been difficult for both political relations as well as the concerned employees. A new battery factory in Oberlausitz may offer relief. However, reports indicate Siemens CEO Jae Kaeser has commented he is planning to meet the challenge head on, and to save and consolidate the production area with the industry concept Oberlausitz. The concept will be designed to meet the ongoing challenge of saving 3,500 jobs, as well as the closure of factories in G\u00f6rlitz, Erfurt, Leipzig and Offenbach. As the coal mining facilities are closing and winding down, a new economic concept will be needed to keep the region at work, as many jobs are dependent on the industry present in the areas. A step towards renewable energy production will prove to be more long-lived and will provide the region with new significance. The move is planned to take place in the next 2-5 years. This would include large scale infrastructural changes as well as the construction of a new industry park. Whether they will receive subsidies for the plans is not yet clear, however the existing expertise and partnerships maintained by Siemens is certainly sufficient to transform the region. It would also heavily expand Germany\u2019s industrial capabilities regarding environmentally friendly technologies and breathe new life into the region. faz.net(in German)",
#     "nodes": [
#         {
#             "article_id": "67b1e4260554959fd725ee08",
#             "id": "siemens",
#             "type": "company",
#             "name": "Siemens",
#             "parent_company": null,
#             "subsidiaries": [],
#             "location": {
#                 "city": "",
#                 "country": ""
#             },
#             "products": []
#         },
#         {
#             "article_id": "67b1e4260554959fd725ee08",
#             "id": "factory_goerlitz",
#             "type": "factory",
#             "name": "Siemens Turbine Factory",
#             "parent_company": null,
#             "subsidiaries": [],
#             "location": {
#                 "city": "Goerlitz",
#                 "country": "Germany"
#             },
#             "products": [
#                 "turbines"
#             ]
#         },
#         {
#             "article_id": "67b1e4260554959fd725ee08",
#             "id": "factory_oberlausitz",
#             "type": "factory",
#             "name": "New Battery Factory",
#             "parent_company": null,
#             "subsidiaries": [],
#             "location": {
#                 "city": "Oberlausitz",
#                 "country": "Germany"
#             },
#             "products": [
#                 "batteries"
#             ]
#         }
#     ]
# }
# --- Article 5 ---
# {
#     "_id": {
#         "$oid": "67b1e4260554959fd725ee09"
#     },
#     "title": "Tesla loses senior battery engineer Ernest Villanueva",
#     "paragraphs": [
#         {
#             "p1": "It took a bit for the news to reach the public but Tesla\u2019s leading battery engineer Ernest Villanueva has packed up last year. Having worked there since 2006, he had a hand in designing the battery packs of all Tesla models including the Roadster and holds various patents.",
#             "p2": "Tesla has lost a key figure in Ernest Villanueva andCNBCquotes his LinkedIn profile, according to which Villanueva most recently held the title of Senior Manager of Battery Module Design. A person close to the matter said though that he has left the firm already some months ago.",
#             "p3": "The engineer had started to work at Tesla in 2006 and has thus helped design battery modules for all the Tesla cars, starting with the Roadster and up to the Model 3.",
#             "p4": "His departure may have to do with the production problems of the Model 3 that had been blamed on battery assembly.",
#             "p5": "Villanueva is also not the only high ranking Tesla man to have left the company. Jason Mendez and Will McColl have quit their jobs earlier this month. Both were involved in stepping up automation of the Model 3\u2019s production line (wereported).",
#             "p6": "Tesla declined to comment in all cases. Elon Musk though has justrecently extendedhis contract as Tesla CEO by another ten years.",
#             "p7": "cnbc.com"
#         }
#     ],
#     "meta": {
#         "ID": "1100061",
#         "date": "30-01-2018",
#         "url": "https://www.electrive.com/2018/01/30/tesla-loses-senior-battery-engineer-ernest-villanueva/"
#     },
#     "combined_text": "It took a bit for the news to reach the public but Tesla\u2019s leading battery engineer Ernest Villanueva has packed up last year. Having worked there since 2006, he had a hand in designing the battery packs of all Tesla models including the Roadster and holds various patents. Tesla has lost a key figure in Ernest Villanueva andCNBCquotes his LinkedIn profile, according to which Villanueva most recently held the title of Senior Manager of Battery Module Design. A person close to the matter said though that he has left the firm already some months ago. The engineer had started to work at Tesla in 2006 and has thus helped design battery modules for all the Tesla cars, starting with the Roadster and up to the Model 3. His departure may have to do with the production problems of the Model 3 that had been blamed on battery assembly. Villanueva is also not the only high ranking Tesla man to have left the company. Jason Mendez and Will McColl have quit their jobs earlier this month. Both were involved in stepping up automation of the Model 3\u2019s production line (wereported). Tesla declined to comment in all cases. Elon Musk though has justrecently extendedhis contract as Tesla CEO by another ten years. cnbc.com",
#     "nodes": [
#         {
#             "article_id": "67b1e4260554959fd725ee09",
#             "id": "tesla",
#             "type": "company",
#             "name": "Tesla",
#             "parent_company": null,
#             "subsidiaries": [],
#             "location": {
#                 "city": "",
#                 "country": ""
#             },
#             "products": []
#         }
#     ]
# }

# %%
def read_prompt_from_file_only(file_path):
    with open(file_path, 'r') as file:
        prompt = file.read()
    return prompt

def combine_paragraphs(article):
    paragraphs = article.get('paragraphs', [])
    # Handle missing or empty paragraphs
    if not paragraphs:
        print("⚠️ No paragraphs found in the article.")
        return ""

    combined_text = ""
    for para_obj in paragraphs:
        for key in sorted(para_obj.keys()):
            combined_text += para_obj[key].strip() + " "

    return combined_text.strip()

# %%
function_schema = {
    "name": "extract_clean_tech_entities",
    "description": "Extracts structured entities and relationships from a clean technology investment article.",
    "parameters": {
        "type": "object",
        "properties": {
            "nodes": {
                "type": "object",
                "properties": {
                    "companies": {
                        "type": "array",
                        "items": {
                            "type": "object",
                            "properties": {
                                "id": {"type": "string"},
                                "type": {"const": "Company"},
                                "name": {"type": "string"}
                            },
                            "required": ["id", "type", "name"]
                        }
                    },
                    "joint_ventures": {
                        "type": "array",
                        "items": {
                            "type": "object",
                            "properties": {
                                "id": {"type": "string"},
                                "type": {"const": "JV"},
                                "name": {"type": "string"}
                            },
                            "required": ["id", "type", "name"]
                        }
                    },
                    "factories": {
                        "type": "array",
                        "items": {
                            "type": "object",
                            "properties": {
                                "id": {"type": "string"},
                                "type": {"const": "Factory"},
                                "name": {"type": "string"},
                                "location": {
                                    "type": "object",
                                    "properties": {
                                        "city": {"type": "string"},
                                        "country": {"type": "string"}
                                    },
                                    "required": ["city", "country"]
                                }
                            },
                            "required": ["id", "type", "name", "location"]
                        }
                    },
                    "investments": {
                        "type": "array",
                        "items": {
                            "type": "object",
                            "properties": {
                                "id": {"type": "string"},
                                "type": {"const": "Investment"},
                                "name": {"type": "string"},
                                "amount": {"type": "string"},
                                "status": {
                                    "type": "string",
                                    "enum": ["announced", "ongoing", "completed"]
                                }
                            },
                            "required": ["id", "type", "name", "amount", "status"]
                        }
                    },
                    "capacities": {
                        "type": "array",
                        "items": {
                            "type": "object",
                            "properties": {
                                "id": {"type": "string"},
                                "type": {"const": "Capacity"},
                                "amount": {"type": "string"},
                                "status": {
                                    "type": "string",
                                    "enum": ["announced", "under construction", "operational"]
                                }
                            },
                            "required": ["id", "type", "amount", "status"]
                        }
                    },
                    "products": {
                        "type": "array",
                        "items": {
                            "type": "object",
                            "properties": {
                                "id": {"type": "string"},
                                "type": {"const": "Product"},
                                "name": {"type": "string"}
                            },
                            "required": ["id", "type", "name"]
                        }
                    }
                },
                "required": [
                    "companies",
                    "joint_ventures",
                    "factories",
                    "investments",
                    "capacities",
                    "products"
                ]
            },
            "relationships": {
                "type": "array",
                "items": {
                    "type": "object",
                    "properties": {
                        "source": {"type": "string"},
                        "target": {"type": "string"},
                        "type": {
                            "type": "string",
                            "enum": [
                                "forms",
                                "owns",
                                "makes",
                                "funds",
                                "enables",
                                "targets",
                                "has",
                                "produces"
                            ]
                        }
                    },
                    "required": ["source", "target", "type"]
                }
            }
        },
        "required": ["nodes", "relationships"]
    }
}

# %%
def extract_nodes(article_id, text, PROMPT_PATH):
    prompt = read_prompt_from_file_only(PROMPT_PATH)

    try:
        completion = client.chat.completions.create(
            model="gpt-4o",
            messages=[
                {"role": "system", "content": prompt},
                {"role": "user", "content": f"Here is the article: {text}"}
            ],
            functions = [function_schema],
            function_call = {"name": "extract_clean_tech_entities"},
            temperature=0
        )

        # parse the returned function call
        function_args = completion.choices[0].message.function_call.arguments
        extracted_data = json.loads(function_args)
        print(f"✅ Retrieved nodes {extracted_data}\n")

        if "nodes" not in extracted_data:
            raise ValueError("Expected 'nodes' key in LLM output but not found.")

        nodes_by_type = extracted_data["nodes"]
        relationships = extracted_data["relationships"]

        # Flatten nodes while retaining their type
        formatted_nodes = []
        for node_type, node_list in nodes_by_type.items():
            for node in node_list:
                formatted_node = {
                    "article_id": article_id,
                    "id": node.get("id"),
                    "type": node.get("type"),
                    "name": node.get("name"),
                    "location": {
                        "city": node.get("location", {}).get("city", ""),
                        "country": node.get("location", {}).get("country", "")
                    } if node.get("location") else None,
                    "amount": node.get("amount"),
                    "status": node.get("status"),
                }
                formatted_nodes.append(formatted_node)

        formatted_relations = []
        for relation in relationships:
            formatted_relationships = {
                "article_id": article_id,
                "source": relation.get("source"),
                "target": relation.get("target"),
                "type": relation.get("type"),
            }
            formatted_relations.append(formatted_relationships)

        return formatted_nodes, formatted_relations

    except json.JSONDecodeError as e:
        print(f"❌ JSON Parsing Error: {e}")
        return []
    except Exception as e:
        print(f"❌ Error extracting nodes: {e}")
        return []

# %%
def process_articles(limit, offset, PROMPT_PATH):
    # Retrieve articles with limit & offset, sorted by `_id` for consistency
    articles_to_process = list(
        articles_collection.find({}, {"_id": 1, "paragraphs": 1})  # Fetch paragraphs instead of text
        .sort("_id", 1)  # Sort by MongoDB ObjectId (ascending)
        .skip(offset)    # Skip first `offset` articles
        .limit(limit)   # Limit the number of articles
    )

    print(f"🔹 Processing {len(articles_to_process)} articles (Offset: {offset})")

    for article in articles_to_process:
        articleID = str(article["_id"])  # Convert ObjectId to string

        # Extract text from paragraphs
        text = combine_paragraphs(article)

        # Skip if no text is extracted
        if not text:
            print(f"⚠️ No valid text found for Article ID: {articleID}. Skipping.")
            continue

        print(f"📌 Processing Article ID: {articleID}")

        try:
            # Extract and format nodes
            formatted_nodes, formatted_relations = extract_nodes(articleID, text, PROMPT_PATH)

            # Ensure extracted nodes are valid before insertion
            if not formatted_nodes:
                print(f"⚠️ No nodes extracted for Article ID: {articleID}. Skipping update.")
                continue

            # Update the article document with extracted nodes and combined text
            update_result = articles_collection.update_one(
                {"_id": article["_id"]},  # Match by article ID
                {"$set": {"combined_text": text, "all_nodes_3": formatted_nodes, "all_relationships_3": formatted_relations}}  # Add new fields
            )

            # Log success
            if update_result.modified_count > 0:
                print(f"✅ Updated Article ID: {articleID} with {len(formatted_nodes)} nodes, {len(formatted_relations)} relationships and combined text.")
            else:
                print(f"⚠️ No updates made for Article ID: {articleID}.")

        except Exception as e:
            print(f"❌ Error processing Article ID {articleID}: {e}")

# %%
PROMPT_PATH = "entity-relationships-func-call.txt"

process_articles(10,0, PROMPT_PATH)
# Out:
# 🔹 Processing 10 articles (Offset: 0)
# 📌 Processing Article ID: 67b1e41e0554959fd725edf6
# ✅ Retrieved nodes {'nodes': {'companies': [{'id': 'company_1', 'type': 'Company', 'name': 'Mitsubishi Chemical'}], 'joint_ventures': [], 'factories': [{'id': 'factory_1', 'type': 'Factory', 'name': 'UK Plant', 'location': {'city': 'null', 'country': 'Britain'}}, {'id': 'factory_2', 'type': 'Factory', 'name': 'US Plant', 'location': {'city': 'null', 'country': 'States'}}, {'id': 'factory_3', 'type': 'Factory', 'name': 'China Plant', 'location': {'city': 'null', 'country': 'China'}}], 'investments': [], 'capacities': [], 'products': [{'id': 'product_1', 'type': 'Product', 'name': 'Battery Electrolyte'}, {'id': 'product_2', 'type': 'Product', 'name': 'Mobile Device Battery'}]}, 'relationships': [{'source': 'company_1', 'target': 'factory_1', 'type': 'owns'}, {'source': 'company_1', 'target': 'factory_2', 'type': 'owns'}, {'source': 'company_1', 'target': 'factory_3', 'type': 'owns'}, {'source': 'factory_1', 'target': 'product_1', 'type': 'produces'}, {'source': 'factory_1', 'target': 'product_2', 'type': 'produces'}]}
#
# ✅ Updated Article ID: 67b1e41e0554959fd725edf6 with 6 nodes, 5 relationships and combined text.
# 📌 Processing Article ID: 67b1e41f0554959fd725edf7
# ✅ Retrieved nodes {'nodes': {'companies': [{'id': 'company_1', 'type': 'Company', 'name': 'BYD'}], 'joint_ventures': [], 'factories': [{'id': 'factory_1', 'type': 'Factory', 'name': 'Battery Recycling Facility', 'location': {'city': 'Shanghai', 'country': 'China'}}], 'investments': [], 'capacities': [], 'products': [{'id': 'product_1', 'type': 'Product', 'name': 'Electric Vehicle Batteries'}, {'id': 'product_2', 'type': 'Product', 'name': 'Energy Storage Batteries'}, {'id': 'product_3', 'type': 'Product', 'name': 'Solar Module'}]}, 'relationships': [{'source': 'company_1', 'target': 'factory_1', 'type': 'owns'}, {'source': 'factory_1', 'target': 'product_1', 'type': 'produces'}, {'source': 'factory_1', 'target': 'product_2', 'type': 'produces'}]}
#
# ✅ Updated Article ID: 67b1e41f0554959fd725edf7 with 5 nodes, 3 relationships and combined text.
# 📌 Processing Article ID: 67b1e41f0554959fd725edf8
# ✅ Retrieved nodes {'nodes': {'companies': [{'id': 'company_1', 'type': 'Company', 'name': 'BASF'}, {'id': 'company_2', 'type': 'Company', 'name': 'Toda'}, {'id': 'company_3', 'type': 'Company', 'name': 'BASF Toda America'}, {'id': 'company_4', 'type': 'Company', 'name': 'Norilsk Nickel (Nornickel)'}, {'id': 'company_5', 'type': 'Company', 'name': 'Sion Power'}], 'joint_ventures': [{'id': 'joint_venture_1', 'type': 'Joint Venture', 'name': 'BASF Toda Battery Materials'}], 'factories': [{'id': 'factory_1', 'type': 'Factory', 'name': 'Elyria Factory', 'location': {'city': 'Elyria', 'country': 'USA'}}, {'id': 'factory_2', 'type': 'Factory', 'name': 'Battle Creek Factory', 'location': {'city': 'Battle Creek', 'country': 'USA'}}, {'id': 'factory_3', 'type': 'Factory', 'name': 'Onoda Plant', 'location': {'city': 'Onoda', 'country': 'Japan'}}], 'investments': [{'id': 'investment_1', 'type': 'Investment', 'name': 'BASF Europe Investment', 'amount': '400m euros', 'status': 'announced'}], 'capacities': [{'id': 'capacity_1', 'type': 'Capacity', 'amount': 'null', 'status': 'operational'}], 'products': [{'id': 'product_1', 'type': 'Product', 'name': 'NCM cathode materials'}, {'id': 'product_2', 'type': 'Product', 'name': 'NCA cathode materials'}, {'id': 'product_3', 'type': 'Product', 'name': 'cathode materials with high nickel percentage'}, {'id': 'product_4', 'type': 'Product', 'name': 'Li-metal batteries'}]}, 'relationships': [{'source': 'company_1', 'target': 'joint_venture_1', 'type': 'forms'}, {'source': 'company_2', 'target': 'joint_venture_1', 'type': 'forms'}, {'source': 'company_3', 'target': 'product_1', 'type': 'targets'}, {'source': 'company_3', 'target': 'product_2', 'type': 'targets'}, {'source': 'joint_venture_1', 'target': 'factory_1', 'type': 'owns'}, {'source': 'joint_venture_1', 'target': 'factory_2', 'type': 'owns'}, {'source': 'factory_3', 'target': 'capacity_1', 'type': 'has'}, {'source': 'factory_3', 'target': 'product_3', 'type': 'produces'}, {'source': 'investment_1', 'target': 'product_1', 'type': 'targets'}, {'source': 'investment_1', 'target': 'product_2', 'type': 'targets'}, {'source': 'company_1', 'target': 'company_4', 'type': 'forms'}, {'source': 'company_1', 'target': 'company_5', 'type': 'forms'}]}
#
# ✅ Updated Article ID: 67b1e41f0554959fd725edf8 with 15 nodes, 12 relationships and combined text.
# 📌 Processing Article ID: 67b1e41f0554959fd725edf9
# ✅ Retrieved nodes {'nodes': {'companies': [{'id': 'company_1', 'type': 'Company', 'name': 'Forsee Power'}, {'id': 'company_2', 'type': 'Company', 'name': 'Mitsui'}, {'id': 'company_3', 'type': 'Company', 'name': 'European Investment Bank'}], 'joint_ventures': [], 'factories': [{'id': 'factory_1', 'type': 'Factory', 'name': 'Forsee Power Facility', 'location': {'city': 'Greater Paris', 'country': 'France'}}], 'investments': [{'id': 'investment_1', 'type': 'Investment', 'name': 'Forsee Power Investment', 'amount': '55 million euros', 'status': 'announced'}], 'capacities': [{'id': 'capacity_1', 'type': 'Capacity', 'amount': 'tenfold increase', 'status': 'announced'}], 'products': [{'id': 'product_1', 'type': 'Product', 'name': 'battery systems for buses'}, {'id': 'product_2', 'type': 'Product', 'name': 'battery systems for trucks'}, {'id': 'product_3', 'type': 'Product', 'name': 'battery systems for vessels'}, {'id': 'product_4', 'type': 'Product', 'name': 'battery systems for scooters'}]}, 'relationships': [{'source': 'company_1', 'target': 'investment_1', 'type': 'makes'}, {'source': 'investment_1', 'target': 'capacity_1', 'type': 'enables'}, {'source': 'investment_1', 'target': 'factory_1', 'type': 'funds'}, {'source': 'capacity_1', 'target': 'product_1', 'type': 'targets'}, {'source': 'capacity_1', 'target': 'product_2', 'type': 'targets'}, {'source': 'capacity_1', 'target': 'product_3', 'type': 'targets'}, {'source': 'capacity_1', 'target': 'product_4', 'type': 'targets'}, {'source': 'factory_1', 'target': 'capacity_1', 'type': 'has'}, {'source': 'factory_1', 'target': 'product_1', 'type': 'produces'}, {'source': 'factory_1', 'target': 'product_2', 'type': 'produces'}, {'source': 'factory_1', 'target': 'product_3', 'type': 'produces'}, {'source': 'factory_1', 'target': 'product_4', 'type': 'produces'}]}
#
# ✅ Updated Article ID: 67b1e41f0554959fd725edf9 with 10 nodes, 12 relationships and combined text.
# 📌 Processing Article ID: 67b1e4200554959fd725edfa
# ✅ Retrieved nodes {'nodes': {'companies': [{'id': 'company_1', 'type': 'Company', 'name': 'Northvolt'}, {'id': 'company_2', 'type': 'Company', 'name': 'European Investment Bank'}, {'id': 'company_3', 'type': 'Company', 'name': 'Swedish Energy Agency'}, {'id': 'company_4', 'type': 'Company', 'name': 'Scania'}], 'joint_ventures': [], 'factories': [{'id': 'factory_1', 'type': 'Factory', 'name': 'Northvolt Labs', 'location': {'city': 'Västerås', 'country': 'Sweden'}}, {'id': 'factory_2', 'type': 'Factory', 'name': 'Planned Lithium-ion Battery Factory', 'location': {'city': 'Skellefteå', 'country': 'Sweden'}}], 'investments': [{'id': 'investment_1', 'type': 'Investment', 'name': 'European Investment Bank Financing', 'amount': '52.5 million euros', 'status': 'announced'}, {'id': 'investment_2', 'type': 'Investment', 'name': 'Swedish Energy Agency Funding', 'amount': '15 million euros', 'status': 'announced'}, {'id': 'investment_3', 'type': 'Investment', 'name': 'Scania Investment', 'amount': '10 million euros', 'status': 'announced'}], 'capacities': [{'id': 'capacity_1', 'type': 'Capacity', 'amount': '32 GWh', 'status': 'announced'}], 'products': [{'id': 'product_1', 'type': 'Product', 'name': 'Batteries for Transportation'}, {'id': 'product_2', 'type': 'Product', 'name': 'Batteries for Energy Storage'}, {'id': 'product_3', 'type': 'Product', 'name': 'Batteries for Heavy Industrial Vehicles'}]}, 'relationships': [{'source': 'company_1', 'target': 'investment_1', 'type': 'makes'}, {'source': 'company_1', 'target': 'investment_2', 'type': 'makes'}, {'source': 'company_1', 'target': 'investment_3', 'type': 'makes'}, {'source': 'investment_1', 'target': 'factory_1', 'type': 'funds'}, {'source': 'investment_2', 'target': 'factory_1', 'type': 'funds'}, {'source': 'investment_3', 'target': 'factory_1', 'type': 'funds'}, {'source': 'factory_2', 'target': 'capacity_1', 'type': 'has'}, {'source': 'capacity_1', 'target': 'product_1', 'type': 'targets'}, {'source': 'capacity_1', 'target': 'product_2', 'type': 'targets'}, {'source': 'company_1', 'target': 'product_3', 'type': 'targets'}]}
#
# ✅ Updated Article ID: 67b1e4200554959fd725edfa with 13 nodes, 10 relationships and combined text.
# 📌 Processing Article ID: 67b1e4200554959fd725edfb
# ✅ Retrieved nodes {'nodes': {'companies': [{'id': 'company_1', 'type': 'Company', 'name': 'Northvolt'}, {'id': 'company_2', 'type': 'Company', 'name': 'Swedish Energy Agency'}, {'id': 'company_3', 'type': 'Company', 'name': 'Scania'}, {'id': 'company_4', 'type': 'Company', 'name': 'ABB'}, {'id': 'company_5', 'type': 'Company', 'name': 'Vestas'}], 'joint_ventures': [], 'factories': [{'id': 'factory_1', 'type': 'Factory', 'name': 'Northvolt Labs', 'location': {'city': 'Västerås', 'country': 'Sweden'}}, {'id': 'factory_2', 'type': 'Factory', 'name': 'Swedish Gigafactory', 'location': {'city': 'Skellefteå', 'country': 'Sweden'}}], 'investments': [{'id': 'investment_1', 'type': 'Investment', 'name': 'Swedish Energy Agency Grant', 'amount': 'SEK 146m', 'status': 'announced'}, {'id': 'investment_2', 'type': 'Investment', 'name': 'Scania Investment', 'amount': '10 million euros', 'status': 'announced'}, {'id': 'investment_3', 'type': 'Investment', 'name': 'Vestas Investment', 'amount': '10 million euros', 'status': 'announced'}, {'id': 'investment_4', 'type': 'Investment', 'name': 'ABB Investment', 'amount': 'undisclosed', 'status': 'announced'}], 'capacities': [{'id': 'capacity_1', 'type': 'Capacity', 'amount': '8 GWh per year', 'status': 'announced'}, {'id': 'capacity_2', 'type': 'Capacity', 'amount': '32 GWh per year', 'status': 'announced'}], 'products': [{'id': 'product_1', 'type': 'Product', 'name': 'lithium-ion battery'}]}, 'relationships': [{'source': 'company_1', 'target': 'factory_1', 'type': 'owns'}, {'source': 'company_1', 'target': 'factory_2', 'type': 'owns'}, {'source': 'company_2', 'target': 'investment_1', 'type': 'makes'}, {'source': 'company_3', 'target': 'investment_2', 'type': 'makes'}, {'source': 'company_5', 'target': 'investment_3', 'type': 'makes'}, {'source': 'company_4', 'target': 'investment_4', 'type': 'makes'}, {'source': 'investment_1', 'target': 'factory_1', 'type': 'funds'}, {'source': 'investment_2', 'target': 'factory_1', 'type': 'funds'}, {'source': 'investment_3', 'target': 'factory_1', 'type': 'funds'}, {'source': 'investment_4', 'target': 'factory_1', 'type': 'funds'}, {'source': 'investment_1', 'target': 'product_1', 'type': 'targets'}, {'source': 'factory_2', 'target': 'capacity_1', 'type': 'has'}, {'source': 'factory_2', 'target': 'capacity_2', 'type': 'has'}, {'source': 'factory_2', 'target': 'product_1', 'type': 'produces'}]}
#
# ✅ Updated Article ID: 67b1e4200554959fd725edfb with 14 nodes, 14 relationships and combined text.
# 📌 Processing Article ID: 67b1e4210554959fd725edfc
# ✅ Retrieved nodes {'nodes': {'companies': [{'id': 'company_1', 'type': 'Company', 'name': 'Tesla'}, {'id': 'company_2', 'type': 'Company', 'name': 'Sociedad Química y Minera de Chile (SQM)'}, {'id': 'company_3', 'type': 'Company', 'name': 'Toyota'}, {'id': 'company_4', 'type': 'Company', 'name': 'Orocobre'}, {'id': 'company_5', 'type': 'Company', 'name': 'Panasonic'}], 'joint_ventures': [], 'factories': [{'id': 'factory_1', 'type': 'Factory', 'name': 'Gigafactory', 'location': {'city': 'Nevada', 'country': 'USA'}}], 'investments': [], 'capacities': [], 'products': [{'id': 'product_1', 'type': 'Product', 'name': 'Lithium'}]}, 'relationships': [{'source': 'company_1', 'target': 'factory_1', 'type': 'owns'}, {'source': 'factory_1', 'target': 'product_1', 'type': 'produces'}]}
#
# ✅ Updated Article ID: 67b1e4210554959fd725edfc with 7 nodes, 2 relationships and combined text.
# 📌 Processing Article ID: 67b1e4210554959fd725edfd
# ✅ Retrieved nodes {'nodes': {'companies': [], 'joint_ventures': [], 'factories': [{'id': 'factory_1', 'type': 'Factory', 'name': 'Aalen University Facility', 'location': {'city': 'Aalen', 'country': 'Germany'}}], 'investments': [{'id': 'investment_1', 'type': 'Investment', 'name': 'BMBF Subsidy', 'amount': '850,000 euro', 'status': 'announced'}], 'capacities': [], 'products': [{'id': 'product_1', 'type': 'Product', 'name': 'Solid-State Battery Technology'}]}, 'relationships': [{'source': 'investment_1', 'target': 'factory_1', 'type': 'funds'}, {'source': 'factory_1', 'target': 'product_1', 'type': 'produces'}]}
#
# ⚠️ No updates made for Article ID: 67b1e4210554959fd725edfd.
# 📌 Processing Article ID: 67b1e4210554959fd725edfe
# ✅ Retrieved nodes {'nodes': {'companies': [{'id': 'company_1', 'type': 'Company', 'name': 'ZSW'}, {'id': 'company_2', 'type': 'Company', 'name': 'Manz'}, {'id': 'company_3', 'type': 'Company', 'name': 'Freudenberg'}, {'id': 'company_4', 'type': 'Company', 'name': 'Federal Ministry of Education and Research (BMBF)'}], 'joint_ventures': [], 'factories': [{'id': 'factory_1', 'type': 'Factory', 'name': 'ZSW Pilot Line', 'location': {'city': 'Ulm', 'country': 'Germany'}}], 'investments': [{'id': 'investment_1', 'type': 'Investment', 'name': 'STACK Project Funding', 'amount': '2.7 euros', 'status': 'announced'}], 'capacities': [], 'products': [{'id': 'product_1', 'type': 'Product', 'name': 'Li-ion cells'}, {'id': 'product_2', 'type': 'Product', 'name': 'prismatic cells with wound electrodes (PHEV-1 format)'}]}, 'relationships': [{'source': 'company_1', 'target': 'factory_1', 'type': 'owns'}, {'source': 'investment_1', 'target': 'factory_1', 'type': 'funds'}, {'source': 'factory_1', 'target': 'product_1', 'type': 'produces'}, {'source': 'factory_1', 'target': 'product_2', 'type': 'produces'}, {'source': 'investment_1', 'target': 'product_1', 'type': 'targets'}]}
#
# ✅ Updated Article ID: 67b1e4210554959fd725edfe with 8 nodes, 5 relationships and combined text.
# 📌 Processing Article ID: 67b1e4220554959fd725edff
# ✅ Retrieved nodes {'nodes': {'companies': [{'id': 'company_1', 'type': 'Company', 'name': 'A123 Systems'}, {'id': 'company_2', 'type': 'Company', 'name': 'Ionic Materials'}, {'id': 'company_3', 'type': 'Company', 'name': 'Wanxiang'}, {'id': 'company_4', 'type': 'Company', 'name': 'Renault-Nissan-Mitsubishi Alliance'}, {'id': 'company_5', 'type': 'Company', 'name': 'Alliance Ventures'}, {'id': 'company_6', 'type': 'Company', 'name': 'BMW'}, {'id': 'company_7', 'type': 'Company', 'name': 'Solid Power'}], 'joint_ventures': [], 'factories': [{'id': 'factory_1', 'type': 'Factory', 'name': 'Production Facility in Massachusetts', 'location': {'city': 'Massachusetts', 'country': 'USA'}}], 'investments': [{'id': 'investment_1', 'type': 'Investment', 'name': 'A123 Investment in Ionic Materials', 'amount': 'null', 'status': 'announced'}, {'id': 'investment_2', 'type': 'Investment', 'name': 'Ionic Materials Financing Round', 'amount': '65 million dollars', 'status': 'completed'}], 'capacities': [], 'products': [{'id': 'product_1', 'type': 'Product', 'name': 'Solid Polymer Electrolyte'}, {'id': 'product_2', 'type': 'Product', 'name': 'Solid-State Batteries'}]}, 'relationships': [{'source': 'company_1', 'target': 'investment_1', 'type': 'makes'}, {'source': 'investment_1', 'target': 'product_1', 'type': 'targets'}, {'source': 'investment_2', 'target': 'product_1', 'type': 'targets'}, {'source': 'company_5', 'target': 'investment_2', 'type': 'makes'}, {'source': 'factory_1', 'target': 'product_2', 'type': 'produces'}]}
#
# ✅ Updated Article ID: 67b1e4220554959fd725edff with 12 nodes, 5 relationships and combined text.

# %%
articles_collection.find_one({'title': 'BASF and Toda found cathode subsidiary in USA'})
# Out:
# {'_id': ObjectId('67b1e41f0554959fd725edf8'),
#  'title': 'BASF and Toda found cathode subsidiary in USA',
#  'paragraphs': [{'p1': 'The announced founding of a new subsidiary company by BASF and Toda has now been completed. BASF Toda America (BTA) will be making NCM and NCA cathode materials for use in e-mobility. The move is part of BASF’s globalisation strategy.',
#    'p2': 'BASF and Todayannouncedin December that they would be adapting their structures to focus more on expanding their business in the USA, and would be bundling their factories in Elyria, Ohio and Battle Creek, Michigan, under the terms of a joint venture.',
#    'p3': 'The founding of this joint venture marks the second time BASF and Toda are cooperating. The already existing BASF Toda Battery Materials has been preparing to ramp up production capabilities and securing a supply of cathode materials to address the growing e-mobility market in North America.\xa0The German company is hoping to work better with the U.S. market with a local production facility and more direct access to consumers.',
#    'p4': 'BASF is looking to set up local production globally though. The most recent production expansion was\xa0 in the Japanese manufacturing plant in Onoda, which produces cathode materials with a high nickel percentage. Capacities there tripled, and the largest calcination plant has taken up operation there.',
#    'p5': 'The President of BASF’s Catalysts Division, Kenneth Lane said: “With this investment, BASF is executing its vision to establish a global manufacturing presence for battery materials and responding to growing market needs.”',
#    'p6': 'In Europe, BASFannounced already last yearto invest 400m euros to build production plants for cathode materials. The material for those parts will come from Russia and Finland however, where BASF has signed an MoU with Norilsk Nickel (Nornickel) to provide nickel and cobalt.',
#    'p7': 'BASF is currently supplying components for the major vehicle platforms, and is in the qualifying process for emerging technologies that will replace the current models. One example is its recentcooperation with Sion Poweras they seek to develop Li-metal batteries.',
#    'p8': 'basf.com'}],
#  'meta': {'ID': '1100009',
#   'date': '10-03-2018',
#   'url': 'https://www.electrive.com/2018/03/10/basf-and-toda-found-battery-subsidiary/'},
#  'combined_text': 'The announced founding of a new subsidiary company by BASF and Toda has now been completed. BASF Toda America (BTA) will be making NCM and NCA cathode materials for use in e-mobility. The move is part of BASF’s globalisation strategy. BASF and Todayannouncedin December that they would be adapting their structures to focus more on expanding their business in the USA, and would be bundling their factories in Elyria, Ohio and Battle Creek, Michigan, under the terms of a joint venture. The founding of this joint venture marks the second time BASF and Toda are cooperating. The already existing BASF Toda Battery Materials has been preparing to ramp up production capabilities and securing a supply of cathode materials to address the growing e-mobility market in North America.\xa0The German company is hoping to work better with the U.S. market with a local production facility and more direct access to consumers. BASF is looking to set up local production globally though. The most recent production expansion was\xa0 in the Japanese manufacturing plant in Onoda, which produces cathode materials with a high nickel percentage. Capacities there tripled, and the largest calcination plant has taken up operation there. The President of BASF’s Catalysts Division, Kenneth Lane said: “With this investment, BASF is executing its vision to establish a global manufacturing presence for battery materials and responding to growing market needs.” In Europe, BASFannounced already last yearto invest 400m euros to build production plants for cathode materials. The material for those parts will come from Russia and Finland however, where BASF has signed an MoU with Norilsk Nickel (Nornickel) to provide nickel and cobalt. BASF is currently supplying components for the major vehicle platforms, and is in the qualifying process for emerging technologies that will replace the current models. One example is its recentcooperation with Sion Poweras they seek to develop Li-metal batteries. basf.com',
#  'nodes': [{'article_id': '67b1e41f0554959fd725edf8',
#    'id': 'basf',
#    'type': 'company',
#    'name': 'BASF',
#    'parent_company': None,
#    'subsidiaries': ['BASF Toda America'],
#    'location': {'city': '', 'country': ''},
#    'products': []},
#   {'article_id': '67b1e41f0554959fd725edf8',
#    'id': 'toda',
#    'type': 'company',
#    'name': 'Toda',
#    'parent_company': None,
#    'subsidiaries': [],
#    'location': {'city': '', 'country': ''},
#    'products': []},
#   {'article_id': '67b1e41f0554959fd725edf8',
#    'id': 'basf_toda_jv',
#    'type': 'joint_venture',
#    'name': 'BASF & Toda Joint Venture',
#    'parent_company': None,
#    'subsidiaries': [],
#    'location': {'city': '', 'country': ''},
#    'products': []},
#   {'article_id': '67b1e41f0554959fd725edf8',
#    'id': 'factory_elyria',
#    'type': 'factory',
#    'name': 'BASF-Toda Factory in Elyria',
#    'parent_company': None,
#    'subsidiaries': [],
#    'location': {'city': 'Elyria', 'country': 'USA'},
#    'products': ['NCM cathode materials', 'NCA cathode materials']},
#   {'article_id': '67b1e41f0554959fd725edf8',
#    'id': 'factory_battle_creek',
#    'type': 'factory',
#    'name': 'BASF-Toda Factory in Battle Creek',
#    'parent_company': None,
#    'subsidiaries': [],
#    'location': {'city': 'Battle Creek', 'country': 'USA'},
#    'products': ['NCM cathode materials', 'NCA cathode materials']},
#   {'article_id': '67b1e41f0554959fd725edf8',
#    'id': 'factory_onoda',
#    'type': 'factory',
#    'name': 'BASF Factory in Onoda',
#    'parent_company': None,
#    'subsidiaries': [],
#    'location': {'city': 'Onoda', 'country': 'Japan'},
#    'products': ['cathode materials with high nickel percentage']}],
#  'all_nodes': [{'article_id': '67b1e41f0554959fd725edf8',
#    'id': 'basf',
#    'type': 'company',
#    'name': 'BASF',
#    'parent_company': None,
#    'subsidiaries': ['BASF Toda America'],
#    'location': None,
#    'products': [],
#    'company': [],
#    'investment_type': None,
#    'technology': None,
#    'status': None,
#    'operation_start': None,
#    'announcement_date': None,
#    'FID': None,
#    'construction_start': None},
#   {'article_id': '67b1e41f0554959fd725edf8',
#    'id': 'toda',
#    'type': 'company',
#    'name': 'Toda',
#    'parent_company': None,
#    'subsidiaries': [],
#    'location': None,
#    'products': [],
#    'company': [],
#    'investment_type': None,
#    'technology': None,
#    'status': None,
#    'operation_start': None,
#    'announcement_date': None,
#    'FID': None,
#    'construction_start': None},
#   {'article_id': '67b1e41f0554959fd725edf8',
#    'id': 'factory_elyria',
#    'type': 'factory',
#    'name': 'BASF Toda Factory Elyria',
#    'parent_company': None,
#    'subsidiaries': [],
#    'location': {'city': 'Elyria', 'country': 'USA'},
#    'products': [],
#    'company': [],
#    'investment_type': None,
#    'technology': 'NCM and NCA Cathode Materials',
#    'status': None,
#    'operation_start': None,
#    'announcement_date': None,
#    'FID': None,
#    'construction_start': None},
#   {'article_id': '67b1e41f0554959fd725edf8',
#    'id': 'factory_battle_creek',
#    'type': 'factory',
#    'name': 'BASF Toda Factory Battle Creek',
#    'parent_company': None,
#    'subsidiaries': [],
#    'location': {'city': 'Battle Creek', 'country': 'USA'},
#    'products': [],
#    'company': [],
#    'investment_type': None,
#    'technology': 'NCM and NCA Cathode Materials',
#    'status': None,
#    'operation_start': None,
#    'announcement_date': None,
#    'FID': None,
#    'construction_start': None},
#   {'article_id': '67b1e41f0554959fd725edf8',
#    'id': 'investment_001',
#    'type': 'investment',
#    'name': 'BASF Global Manufacturing Presence Investment',
#    'parent_company': None,
#    'subsidiaries': [],
#    'location': None,
#    'products': [],
#    'company': ['basf'],
#    'investment_type': 'factory construction',
#    'technology': 'Cathode Materials',
#    'status': None,
#    'operation_start': None,
#    'amount_value': 400,
#    'amount_currency': 'EUR',
#    'announcement_date': None,
#    'FID': None,
#    'construction_start': None},
#   {'article_id': '67b1e41f0554959fd725edf8',
#    'id': 'capacity_tripled_onoda',
#    'type': 'capacity',
#    'name': None,
#    'parent_company': None,
#    'subsidiaries': [],
#    'location': None,
#    'products': [],
#    'company': [],
#    'investment_type': None,
#    'technology': None,
#    'status': 'operational',
#    'operation_start': None,
#    'announcement_date': None,
#    'FID': None,
#    'construction_start': None}],
#  'all_nodes_1': [{'article_id': '67b1e41f0554959fd725edf8',
#    'id': 'basf',
#    'type': 'company',
#    'name': 'BASF',
#    'parent_company': None,
#    'subsidiaries': ['BASF Toda America'],
#    'location': None,
#    'products': [],
#    'company': [],
#    'investment_type': None,
#    'technology': None,
#    'status': None,
#    'operation_start': None,
#    'announcement_date': None,
#    'FID': None,
#    'construction_start': None},
#   {'article_id': '67b1e41f0554959fd725edf8',
#    'id': 'toda',
#    'type': 'company',
#    'name': 'Toda',
#    'parent_company': None,
#    'subsidiaries': [],
#    'location': None,
#    'products': [],
#    'company': [],
#    'investment_type': None,
#    'technology': None,
#    'status': None,
#    'operation_start': None,
#    'announcement_date': None,
#    'FID': None,
#    'construction_start': None},
#   {'article_id': '67b1e41f0554959fd725edf8',
#    'id': 'factory_elyria',
#    'type': 'factory',
#    'name': 'BASF Toda Factory Elyria',
#    'parent_company': None,
#    'subsidiaries': [],
#    'location': {'city': 'Elyria', 'country': 'USA'},
#    'products': [],
#    'company': [],
#    'investment_type': None,
#    'technology': 'NCM and NCA Cathode Materials',
#    'status': None,
#    'operation_start': None,
#    'announcement_date': None,
#    'FID': None,
#    'construction_start': None},
#   {'article_id': '67b1e41f0554959fd725edf8',
#    'id': 'factory_battle_creek',
#    'type': 'factory',
#    'name': 'BASF Toda Factory Battle Creek',
#    'parent_company': None,
#    'subsidiaries': [],
#    'location': {'city': 'Battle Creek', 'country': 'USA'},
#    'products': [],
#    'company': [],
#    'investment_type': None,
#    'technology': 'NCM and NCA Cathode Materials',
#    'status': None,
#    'operation_start': None,
#    'announcement_date': None,
#    'FID': None,
#    'construction_start': None},
#   {'article_id': '67b1e41f0554959fd725edf8',
#    'id': 'investment_001',
#    'type': 'investment',
#    'name': 'BASF Global Manufacturing Investment',
#    'parent_company': None,
#    'subsidiaries': [],
#    'location': None,
#    'products': [],
#    'company': ['basf'],
#    'investment_type': 'factory construction',
#    'technology': 'Cathode Materials',
#    'status': None,
#    'operation_start': None,
#    'amount_value': 400,
#    'amount_currency': 'EUR',
#    'announcement_date': None,
#    'FID': None,
#    'construction_start': None},
#   {'article_id': '67b1e41f0554959fd725edf8',
#    'id': 'capacity_tripled_onoda',
#    'type': 'capacity',
#    'name': None,
#    'parent_company': None,
#    'subsidiaries': [],
#    'location': None,
#    'products': [],
#    'company': [],
#    'investment_type': None,
#    'technology': None,
#    'status': 'operational',
#    'operation_start': None,
#    'announcement_date': None,
#    'FID': None,
#    'construction_start': None}],
#  'all_nodes_2': [{'article_id': '67b1e41f0554959fd725edf8',
#    'id': 'basf',
#    'type': 'company',
#    'name': 'BASF',
#    'parent_company': None,
#    'subsidiaries': ['BASF Toda America'],
#    'location': None,
#    'products': [],
#    'company': [],
#    'investment_type': None,
#    'technology': None,
#    'status': None,
#    'operation_start': None,
#    'announcement_date': None,
#    'FID': None,
#    'construction_start': None},
#   {'article_id': '67b1e41f0554959fd725edf8',
#    'id': 'toda',
#    'type': 'company',
#    'name': 'Toda',
#    'parent_company': None,
#    'subsidiaries': [],
#    'location': None,
#    'products': [],
#    'company': [],
#    'investment_type': None,
#    'technology': None,
#    'status': None,
#    'operation_start': None,
#    'announcement_date': None,
#    'FID': None,
#    'construction_start': None},
#   {'article_id': '67b1e41f0554959fd725edf8',
#    'id': 'factory_elyria',
#    'type': 'factory',
#    'name': 'BASF Toda Factory Elyria',
#    'parent_company': None,
#    'subsidiaries': [],
#    'location': {'city': 'Elyria', 'country': 'USA'},
#    'products': [],
#    'company': [],
#    'investment_type': None,
#    'technology': 'NCM and NCA Cathode Materials',
#    'status': None,
#    'operation_start': None,
#    'announcement_date': None,
#    'FID': None,
#    'construction_start': None},
#   {'article_id': '67b1e41f0554959fd725edf8',
#    'id': 'factory_battle_creek',
#    'type': 'factory',
#    'name': 'BASF Toda Factory Battle Creek',
#    'parent_company': None,
#    'subsidiaries': [],
#    'location': {'city': 'Battle Creek', 'country': 'USA'},
#    'products': [],
#    'company': [],
#    'investment_type': None,
#    'technology': 'NCM and NCA Cathode Materials',
#    'status': None,
#    'operation_start': None,
#    'announcement_date': None,
#    'FID': None,
#    'construction_start': None},
#   {'article_id': '67b1e41f0554959fd725edf8',
#    'id': 'investment_001',
#    'type': 'investment',
#    'name': 'BASF Global Manufacturing Investment',
#    'parent_company': None,
#    'subsidiaries': [],
#    'location': None,
#    'products': [],
#    'company': ['basf'],
#    'investment_type': 'factory construction',
#    'technology': 'Cathode Materials',
#    'status': None,
#    'operation_start': None,
#    'amount_value': 400,
#    'amount_currency': 'EUR',
#    'amount_financial_unit': None,
#    'announcement_date': None,
#    'FID': None,
#    'construction_start': None},
#   {'article_id': '67b1e41f0554959fd725edf8',
#    'id': 'capacity_tripled_onoda',
#    'type': 'capacity',
#    'name': None,
#    'parent_company': None,
#    'subsidiaries': [],
#    'location': None,
#    'products': [],
#    'company': [],
#    'investment_type': None,
#    'technology': None,
#    'status': 'operational',
#    'operation_start': None,
#    'announcement_date': None,
#    'FID': None,
#    'construction_start': None}],
#  'all_nodes_3': [{'article_id': '67b1e41f0554959fd725edf8',
#    'id': 'company_basf',
#    'type': 'company',
#    'name': 'BASF',
#    'location': None,
#    'amount': None,
#    'status': None},
#   {'article_id': '67b1e41f0554959fd725edf8',
#    'id': 'company_toda',
#    'type': 'company',
#    'name': 'Toda',
#    'location': None,
#    'amount': None,
#    'status': None},
#   {'article_id': '67b1e41f0554959fd725edf8',
#    'id': 'company_bta',
#    'type': 'company',
#    'name': 'BASF Toda America (BTA)',
#    'location': None,
#    'amount': None,
#    'status': None},
#   {'article_id': '67b1e41f0554959fd725edf8',
#    'id': 'company_btbm',
#    'type': 'company',
#    'name': 'BASF Toda Battery Materials',
#    'location': None,
#    'amount': None,
#    'status': None},
#   {'article_id': '67b1e41f0554959fd725edf8',
#    'id': 'company_nornickel',
#    'type': 'company',
#    'name': 'Norilsk Nickel (Nornickel)',
#    'location': None,
#    'amount': None,
#    'status': None},
#   {'article_id': '67b1e41f0554959fd725edf8',
#    'id': 'company_sion_power',
#    'type': 'company',
#    'name': 'Sion Power',
#    'location': None,
#    'amount': None,
#    'status': None},
#   {'article_id': '67b1e41f0554959fd725edf8',
#    'id': 'joint_venture_1',
#    'type': 'joint_venture',
#    'name': 'null',
#    'location': None,
#    'amount': None,
#    'status': None},
#   {'article_id': '67b1e41f0554959fd725edf8',
#    'id': 'factory_elyria',
#    'type': 'factory',
#    'name': 'Factory in Elyria, Ohio',
#    'location': {'city': 'Elyria', 'country': 'USA'},
#    'amount': None,
#    'status': None},
#   {'article_id': '67b1e41f0554959fd725edf8',
#    'id': 'factory_battle_creek',
#    'type': 'factory',
#    'name': 'Factory in Battle Creek, Michigan',
#    'location': {'city': 'Battle Creek', 'country': 'USA'},
#    'amount': None,
#    'status': None},
#   {'article_id': '67b1e41f0554959fd725edf8',
#    'id': 'factory_onoda',
#    'type': 'factory',
#    'name': 'Onoda manufacturing plant',
#    'location': {'city': 'Onoda', 'country': 'Japan'},
#    'amount': None,
#    'status': None},
#   {'article_id': '67b1e41f0554959fd725edf8',
#    'id': 'factory_europe_cathode',
#    'type': 'factory',
#    'name': 'Production Plant for Cathode Materials',
#    'location': {'city': 'null', 'country': 'null'},
#    'amount': None,
#    'status': None},
#   {'article_id': '67b1e41f0554959fd725edf8',
#    'id': 'investment_europe_400',
#    'type': 'investment',
#    'name': '400m euros investment for cathode materials production plants',
#    'location': None,
#    'amount': '400m euros',
#    'status': 'announced'},
#   {'article_id': '67b1e41f0554959fd725edf8',
#    'id': 'investment_onoda',
#    'type': 'investment',
#    'name': 'Investment in global manufacturing presence for battery materials',
#    'location': None,
#    'amount': 'null',
#    'status': 'completed'},
#   {'article_id': '67b1e41f0554959fd725edf8',
#    'id': 'capacity_onoda_tripled',
#    'type': 'capacity',
#    'name': None,
#    'location': None,
#    'amount': 'tripled',
#    'status': 'operational'},
#   {'article_id': '67b1e41f0554959fd725edf8',
#    'id': 'product_NCM',
#    'type': 'product',
#    'name': 'NCM cathode materials',
#    'location': None,
#    'amount': None,
#    'status': None},
#   {'article_id': '67b1e41f0554959fd725edf8',
#    'id': 'product_NCA',
#    'type': 'product',
#    'name': 'NCA cathode materials',
#    'location': None,
#    'amount': None,
#    'status': None},
#   {'article_id': '67b1e41f0554959fd725edf8',
#    'id': 'product_cathode_highNi',
#    'type': 'product',
#    'name': 'cathode materials with a high nickel percentage',
#    'location': None,
#    'amount': None,
#    'status': None},
#   {'article_id': '67b1e41f0554959fd725edf8',
#    'id': 'product_cathode_materials',
#    'type': 'product',
#    'name': 'cathode materials',
#    'location': None,
#    'amount': None,
#    'status': None},
#   {'article_id': '67b1e41f0554959fd725edf8',
#    'id': 'product_Li_metal_batteries',
#    'type': 'product',
#    'name': 'Li-metal batteries',
#    'location': None,
#    'amount': None,
#    'status': None}],
#  'all_relationships_3': [{'article_id': '67b1e41f0554959fd725edf8',
#    'source': 'company_basf',
#    'target': 'joint_venture_1',
#    'type': 'forms'},
#   {'article_id': '67b1e41f0554959fd725edf8',
#    'source': 'company_toda',
#    'target': 'joint_venture_1',
#    'type': 'forms'},
#   {'article_id': '67b1e41f0554959fd725edf8',
#    'source': 'company_basf',
#    'target': 'investment_europe_400',
#    'type': 'makes'},
#   {'article_id': '67b1e41f0554959fd725edf8',
#    'source': 'investment_europe_400',
#    'target': 'factory_europe_cathode',
#    'type': 'funds'},
#   {'article_id': '67b1e41f0554959fd725edf8',
#    'source': 'investment_europe_400',
#    'target': 'product_cathode_materials',
#    'type': 'targets'},
#   {'article_id': '67b1e41f0554959fd725edf8',
#    'source': 'factory_onoda',
#    'target': 'product_cathode_highNi',
#    'type': 'produces'},
#   {'article_id': '67b1e41f0554959fd725edf8',
#    'source': 'factory_onoda',
#    'target': 'capacity_onoda_tripled',
#    'type': 'has'},
#   {'article_id': '67b1e41f0554959fd725edf8',
#    'source': 'company_basf',
#    'target': 'investment_onoda',
#    'type': 'makes'}]}
