# %%
import os
import certifi
from pymongo import MongoClient
from pymongo.server_api import ServerApi
from dotenv import load_dotenv

# Load environment variables from .env file
load_dotenv()

# Get MongoDB credentials from environment variables
MONGO_URI = os.getenv("MONGO_URI")
DB_NAME = os.getenv("MONGO_DB_NAME")
URL_COLLECTION_NAME = os.getenv("MONGO_URLS_NAME")

# Ensure all necessary environment variables are set
if not all([MONGO_URI, DB_NAME, URL_COLLECTION_NAME]):
    print("❌ Missing required environment variables. Check your .env file.")
    exit()



# Create MongoDB client with TLS verification
try:
    client = MongoClient(MONGO_URI, server_api=ServerApi('1'), tlsCAFile=certifi.where())
    db = client[DB_NAME]
    collection = db[URL_COLLECTION_NAME]

    # Verify connection
    client.admin.command('ping')
    print("✅ Connected to MongoDB Atlas!")

except Exception as e:
    print(f"❌ MongoDB Connection Error: {e}")
    exit()
# Out:
# ✅ Connected to MongoDB Atlas!

# %%
import csv
def load_urls_from_csv(file_path, category):
    with open(file_path, newline='') as csvfile:
        reader = list(csv.reader(csvfile))
        print(f"Total URLs found: {len(reader)}")
        for row in reader:
            if row and row[0]:  # Check if the row is not empty and has a URL
                url = row[0].strip()
                document = {
                    'url': url,
                    'category': category,
                    'status': 'extracted'
                }
                try:
                    collection.insert_one(document)
                    print(f"Inserted: {url} with category: {category}")
                except Exception as e:
                    print(f"Error inserting {url}: {e}")
# Out:
# Hello world!

# %% [markdown]
# electrive

# %%
if __name__ == '__main__':
    CSV_FILE_PATH = '/Users/macbookpro/Documents/tuone/version-2/tuone_v6/src/database_urls/URLs/electrive_automobile_urls.csv'
    CSV_FILE_BATTERY = '/Users/macbookpro/Documents/tuone/version-2/tuone_v6/src/database_urls/URLs/electrive_battery_urls.csv'
    CSV_FILE_HYDROGEN = '/Users/macbookpro/Documents/tuone/version-2/tuone_v6/src/database_urls/URLs/electrive_voice_hydrogen_urls.csv'
    load_urls_from_csv(CSV_FILE_PATH,"electrive")
    load_urls_from_csv(CSV_FILE_PATH,"electrive")
    load_urls_from_csv(CSV_FILE_PATH,"electrive")
    print("Done loading URLs to MongoDB.")
# Out:
# Total URLs found: 8662
# Inserted: URL with category: electrive
# Inserted: https://www.electrive.com/2016/01/04/ampere-vehicles-faraday-furture-atieva-tesla/ with category: electrive
# Inserted: https://www.electrive.com/2016/01/04/ford-panasonic-unicycle-solid-electrolyte/ with category: electrive
# Inserted: https://www.electrive.com/2016/01/04/ford-steps-up-ev-patent-applications/ with category: electrive
# Inserted: https://www.electrive.com/2016/01/04/keiji-ohtsu-sae-hoon-kim-filip-brabec/ with category: electrive
# Inserted: https://www.electrive.com/2016/01/04/mercedes-tesla-suzuki-mitsubishi-formula-e-california/ with category: electrive
# Inserted: https://www.electrive.com/2016/01/05/faraday-future-tesla-chevy-toyota-vmoto/ with category: electrive
# Inserted: https://www.electrive.com/2016/01/05/hybrid-taxis-fuel-cell-technology/ with category: electrive
# Inserted: https://www.electrive.com/2016/01/05/india-faraday-future-mercedes-ecocar/ with category: electrive
# Inserted: https://www.electrive.com/2016/01/05/one-tesla-drivers-sells-188-model-s/ with category: electrive
# Inserted: https://www.electrive.com/2016/01/05/rupert-stadler-elmar-degenhart-opec/ with category: electrive
# Inserted: https://www.electrive.com/2016/01/06/bmw-evatran-gm-aguri/ with category: electrive
# Inserted: https://www.electrive.com/2016/01/06/ev-sales-in-denmark-3/ with category: electrive
# Inserted: https://www.electrive.com/2016/01/06/nick-sampson-mark-reuss/ with category: electrive
# Inserted: https://www.electrive.com/2016/01/06/tesla-model-x-detroit-electric/ with category: electrive
# Inserted: https://www.electrive.com/2016/01/06/volkswagen-honda-gm-citroen-gogoro-byd-india/ with category: electrive
# Inserted: https://www.electrive.com/2016/01/07/chevy-bolt-tesla-qoros-kia-lexus/ with category: electrive
# Inserted: https://www.electrive.com/2016/01/07/ev-registrations-in-norway-2/ with category: electrive
# Inserted: https://www.electrive.com/2016/01/07/herbert-diess-klaus-frohlich-david-adams/ with category: electrive
# Inserted: https://www.electrive.com/2016/01/07/kreisel-electric-nissan-volkswagen-faraday-future/ with category: electrive
# Inserted: https://www.electrive.com/2016/01/07/volkswagen-budd-e-tesla-gigafactory/ with category: electrive
# Inserted: https://www.electrive.com/2016/01/08/byd-tesla-events/ with category: electrive
# Inserted: https://www.electrive.com/2016/01/08/electric-car-sales-in-the-u-s/ with category: electrive
# Inserted: https://www.electrive.com/2016/01/08/formula-e-phinergy-nasa-kongsberg-automotive/ with category: electrive
# Inserted: https://www.electrive.com/2016/01/08/hyundai-chevrolet-mellow-boards-mini-baojun-e100/ with category: electrive
# Inserted: https://www.electrive.com/2016/01/08/mary-barra-gordon-wagener-mark-fields/ with category: electrive
# Inserted: https://www.electrive.com/2016/01
'/Users/macbookpro/Documents/tuone/version-2/tuone_v6/src/database_urls/URLs/electrive_voice_hydrogen_urls.csv'
# ----> 5 load_urls_from_csv(CSV_FILE_PATH,"electrive")
#       6 load_urls_from_csv(CSV_FILE_PATH,"electrive")
#       7 load_urls_from_csv(CSV_FILE_PATH,"electrive")
#
# Cell In[13], line 16, in load_urls_from_csv(file_path, category)
#      10 document = {
#      11     'url': url,
#      12     'category': category,
#      13     'status': 'extracted'
#      14 }
#      15 try:
# ---> 16     collection.insert_one(document)
#      17     print(f"Inserted: {url} with category: {category}")
#      18 except Exception as e:
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pymongo/collection.py:669, in Collection.insert_one(self, document, bypass_document_validation, session, comment)
#     665     document["_id"] = ObjectId()  # type: ignore[index]
#     667 write_concern = self._write_concern_for(session)
#     668 return InsertOneResult(
# --> 669     self._insert_one(
#     670         document,
#     671         ordered=True,
#     672         write_concern=write_concern,
#     673         op_id=None,
#     674         bypass_doc_val=bypass_document_validation,
#     675         session=session,
#     676         comment=comment,
#     677     ),
#     678     write_concern.acknowledged,
#     679 )
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pymongo/collection.py:609, in Collection._insert_one(self, doc, ordered, write_concern, op_id, bypass_doc_val, session, comment)
#     597     result = conn.command(
#     598         self.__database.name,
#     599         command,
#    (...)
#     604         retryable_write=retryable_write,
#     605     )
#     607     _check_write_command_response(result)
# --> 609 self.__database.client._retryable_write(acknowledged, _insert_command, session)
#     611 if not isinstance(doc, RawBSONDocument):
#     612     return doc.get("_id")
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pymongo/mongo_client.py:1523, in MongoClient._retryable_write(self, retryable, func, session, bulk)
#    1509 """Execute an operation with consecutive retries if possible
#    1510
#    1511 Returns func()'s return value on success. On error retries the same
#    (...)
#    1520   - `bulk`: bulk abstraction to execute operations in bulk, defaults to None
#    1521 """
#    1522 with self._tmp_session(session) as s:
# -> 1523     return self._retry_with_session(retryable, func, s, bulk)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pymongo/mongo_client.py:1421, in MongoClient._retry_with_session(self, retryable, func, session, bulk)
#    1416 # Ensure that the options supports retry_writes and there is a valid session not in
#    1417 # transaction, otherwise, we will not support retry behavior for this txn.
#    1418 retryable = bool(
#    1419     retryable and self.options.retry_writes and session and not session.in_transaction
#    1420 )
# -> 1421 return self._retry_internal(
#    1422     func=func,
#    1423     session=session,
#    1424     bulk=bulk,
#    1425     retryable=retryable,
#    1426 )
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pymongo/_csot.py:107, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     105         with _TimeoutContext(timeout):
#     106             return func(self, *args, **kwargs)
# --> 107 return func(self, *args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pymongo/mongo_client.py:1462, in MongoClient._retry_internal(self, func, session, bulk, is_read, address, read_pref, retryable)
#    1428 @_csot.apply
#    1429 def _retry_internal(
#    1430     self,
#    (...)
#    1437     retryable: bool = False,
#    1438 ) -> T:
#    1439     """Internal retryable helper for all client transactions.
#    1440
#    1441     :Parameters:
#    (...)
#    1451       Output of the calling func()
#    1452     """
#    1453     return _ClientConnectionRetryable(
#    1454         mongo_client=self,
#    1455         func=func,
#    1456         bulk=bulk,
#    1457         is_read=is_read,
#    1458         session=session,
#    1459         read_pref=read_pref,
#    1460         address=address,
#    1461         retryable=retryable,
# -> 1462     ).run()
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pymongo/mongo_client.py:2315, in _ClientConnectionRetryable.run(self)
#    2313 self._check_last_error(check_csot=True)
#    2314 try:
# -> 2315     return self._read() if self._is_read else self._write()
#    2316 except ServerSelectionTimeoutError:
#    2317     # The application may think the write was never attempted
#    2318     # if we raise ServerSelectionTimeoutError on the retry
#    2319     # attempt. Raise the original exception instead.
#    2320     self._check_last_error()
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pymongo/mongo_client.py:2423, in _ClientConnectionRetryable._write(self)
#    2421             self._check_last_error()
#    2422             self._retryable = False
# -> 2423         return self._func(self._session, conn, self._retryable)  # type: ignore
#    2424 except PyMongoError as exc:
#    2425     if not self._retryable:
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pymongo/collection.py:597, in Collection._insert_one.<locals>._insert_command(session, conn, retryable_write)
#     594 if bypass_doc_val:
#     595     command["bypassDocumentValidation"] = True
# --> 597 result = conn.command(
#     598     self.__database.name,
#     599     command,
#     600     write_concern=write_concern,
#     601     codec_options=self.__write_response_codec_options,
#     602     session=session,
#     603     client=self.__database.client,
#     604     retryable_write=retryable_write,
#     605 )
#     607 _check_write_command_response(result)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pymongo/helpers.py:322, in _handle_reauth.<locals>.inner(*args, **kwargs)
#     319 from pymongo.pool import Connection
#     321 try:
# --> 322     return func(*args, **kwargs)
#     323 except OperationFailure as exc:
#     324     if no_reauth:
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pymongo/pool.py:996, in Connection.command(self, dbname, spec, read_preference, codec_options, check, allowable_errors, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#     994 # Catch socket.error, KeyboardInterrupt, etc. and close ourselves.
#     995 except BaseException as error:
# --> 996     self._raise_connection_failure(error)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pymongo/pool.py:968, in Connection.command(self, dbname, spec, read_preference, codec_options, check, allowable_errors, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#     966     self._raise_if_not_writable(unacknowledged)
#     967 try:
# --> 968     return command(
#     969         self,
#     970         dbname,
#     971         spec,
#     972         self.is_mongos,
#     973         read_preference,
#     974         codec_options,
#     975         session,
#     976         client,
#     977         check,
#     978         allowable_errors,
#     979         self.address,
#     980         listeners,
#     981         self.max_bson_size,
#     982         read_concern,
#     983         parse_write_concern_error=parse_write_concern_error,
#     984         collation=collation,
#     985         compression_ctx=self.compression_context,
#     986         use_op_msg=self.op_msg_enabled,
#     987         unacknowledged=unacknowledged,
#     988         user_fields=user_fields,
#     989         exhaust_allowed=exhaust_allowed,
#     990         write_concern=write_concern,
#     991     )
#     992 except (OperationFailure, NotPrimaryError):
#     993     raise
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pymongo/network.py:182, in command(conn, dbname, spec, is_mongos, read_preference, codec_options, session, client, check, allowable_errors, address, listeners, max_bson_size, read_concern, parse_write_concern_error, collation, compression_ctx, use_op_msg, unacknowledged, user_fields, exhaust_allowed, write_concern)
#     180     response_doc: _DocumentOut = {"ok": 1}
#     181 else:
# --> 182     reply = receive_message(conn, request_id)
#     183     conn.more_to_come = reply.more_to_come
#     184     unpacked_docs = reply.unpack_response(
#     185         codec_options=codec_options, user_fields=user_fields
#     186     )
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pymongo/network.py:257, in receive_message(conn, request_id, max_message_size)
#     255         deadline = None
#     256 # Ignore the response's request id.
# --> 257 length, _, response_to, op_code = _UNPACK_HEADER(_receive_data_on_socket(conn, 16, deadline))
#     258 # No request_id for exhaust cursor "getMore".
#     259 if request_id is not None:
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pymongo/network.py:340, in _receive_data_on_socket(conn, length, deadline)
#     338     if _csot.get_timeout() and deadline is not None:
#     339         conn.set_conn_timeout(max(deadline - time.monotonic(), 0))
# --> 340     chunk_length = conn.conn.recv_into(mv[bytes_read:])
#     341 except BLOCKING_IO_ERRORS:
#     342     raise socket.timeout("timed out") from None
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/ssl.py:1304, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1300     if flags != 0:
#    1301         raise ValueError(
#    1302           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1303           self.__class__)
# -> 1304     return self.read(nbytes, buffer)
#    1305 else:
#    1306     return super().recv_into(buffer, nbytes, flags)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/ssl.py:1138, in SSLSocket.read(self, len, buffer)
#    1136 try:
#    1137     if buffer is not None:
# -> 1138         return self._sslobj.read(len, buffer)
#    1139     else:
#    1140         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# offshorewind

# %%
if __name__ == '__main__':
    CSV_FILE_PATH = '/Users/macbookpro/Documents/tuone/version-2/tuone_v6/src/database_urls/URLs/offshoreWindBiz_urls.csv'
    load_urls_from_csv(CSV_FILE_PATH,"offshorewind")
    print("Done loading URLs to MongoDB.")

# %% [markdown]
# power technology

# %%
if __name__ == '__main__':
    CSV_FILE_PATH = '/Users/macbookpro/Documents/tuone/version-2/tuone_v6/src/database_urls/URLs/power_technology_urls.csv'
    load_urls_from_csv(CSV_FILE_PATH,"powertechnology")
    print("Done loading URLs to MongoDB.")

# %% [markdown]
# pv-magazine

# %%
if __name__ == '__main__':
    CSV_FILE_PATH = '/Users/macbookpro/Documents/tuone/version-2/tuone_v6/src/database_urls/URLs/pv_magazine_balance-of-system_urls.csv'
    CSV_FILE_BALANCE_SYSTEMS = '/Users/macbookpro/Documents/tuone/version-2/tuone_v6/src/database_urls/URLs/pv_magazine_energy-storage_urls.csv'
    CSV_FILE_ENERGY_STORAGE = '/Users/macbookpro/Documents/tuone/version-2/tuone_v6/src/database_urls/URLs/pv_magazine_hydrogen_urls.csv'
    CSV_FILE_PATH_MANUAFACTURING = '/Users/macbookpro/Documents/tuone/version-2/tuone_v6/src/database_urls/URLs/pv_magazine_manufacturing_urls.csv'
    CSV_FILE_PATH_UTILITY = '/Users/macbookpro/Documents/tuone/version-2/tuone_v6/src/database_urls/URLs/pv_magazine_utility_urls.csv'
    load_urls_from_csv(CSV_FILE_PATH,"pvmagazine")
    load_urls_from_csv(CSV_FILE_BALANCE_SYSTEMS,"pvmagazine")
    load_urls_from_csv(CSV_FILE_ENERGY_STORAGE,"pvmagazine")
    load_urls_from_csv(CSV_FILE_PATH_MANUAFACTURING,"pvmagazine")
    load_urls_from_csv(CSV_FILE_PATH_UTILITY,"pvmagazine")
    print("Done loading URLs to MongoDB.")

# %% [markdown]
# renewsBiz

# %%
if __name__ == '__main__':
    CSV_FILE_PATH_OFFSHORE = '/Users/macbookpro/Documents/tuone/version-2/tuone_v6/src/database_urls/URLs/renewsBiz_offshore_wind_urls.csv'
    CSV_FILE_PATH_ONSHORE = '/Users/macbookpro/Documents/tuone/version-2/tuone_v6/src/database_urls/URLs/renewsBiz_onshore_wind_urls.csv'
    CSV_FILE_PATH_SOLAR = '/Users/macbookpro/Documents/tuone/version-2/tuone_v6/src/database_urls/URLs/renewsBiz_solar_urls.csv'
    load_urls_from_csv( CSV_FILE_PATH_OFFSHORE,"renewsBiz")
    load_urls_from_csv(CSV_FILE_PATH_ONSHORE,"renewsBiz")
    load_urls_from_csv(CSV_FILE_PATH_SOLAR,"renewsBiz")
    print("Done loading URLs to MongoDB.")

# %% [markdown]
# sunfire

# %%
if __name__ == '__main__':
    CSV_FILE_PATH = '/Users/macbookpro/Documents/tuone/version-2/tuone_v6/src/database_urls/URLs/sunfire_urls.csv'
    load_urls_from_csv(CSV_FILE_PATH,"sunfire")
    print("Done loading URLs to MongoDB.")

# %% [markdown]
# World energy

# %%
if __name__ == '__main__':
    CSV_FILE_BATTERY = '/Users/macbookpro/Documents/tuone/version-2/tuone_v6/src/database_urls/URLs/world_energy_battery_urls.csv'
    CSV_FILE_GEOTHERMAL = '/Users/macbookpro/Documents/tuone/version-2/tuone_v6/src/database_urls/URLs/world_energy_geothermal_urls.csv'
    CSV_FILE_HYDROGEN = '/Users/macbookpro/Documents/tuone/version-2/tuone_v6/src/database_urls/URLs/world_energy_hydrogen_urls.csv'
    CSV_FILE_HYDROPOWER = '/Users/macbookpro/Documents/tuone/version-2/tuone_v6/src/database_urls/URLs/world_energy_hydropower_urls.csv'
    CSV_FILE_NUCLEAR = '/Users/macbookpro/Documents/tuone/version-2/tuone_v6/src/database_urls/URLs/world_energy_nuclear_urls.csv'
    CSV_FILE_SOLAR = '/Users/macbookpro/Documents/tuone/version-2/tuone_v6/src/database_urls/URLs/world_energy_solar_urls.csv'
    CSV_FILE_VEHICLES = '/Users/macbookpro/Documents/tuone/version-2/tuone_v6/src/database_urls/URLs/world_energy_vehicles_urls.csv'
    CSV_FILE_WIND = '/Users/macbookpro/Documents/tuone/version-2/tuone_v6/src/database_urls/URLs/world_energy_wind_urls.csv'
    load_urls_from_csv( CSV_FILE_BATTERY,"world_energy")
    load_urls_from_csv(CSV_FILE_GEOTHERMAL,"world_energy")
    load_urls_from_csv(CSV_FILE_HYDROGEN,"world_energy")
    load_urls_from_csv( CSV_FILE_HYDROPOWER,"world_energy")
    load_urls_from_csv(CSV_FILE_NUCLEAR,"world_energy")
    load_urls_from_csv(CSV_FILE_NUCLEAR,"world_energy")
    load_urls_from_csv( CSV_FILE_NUCLEAR,"world_energy")
    print("Done loading URLs to MongoDB.")
