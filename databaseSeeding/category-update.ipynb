# %%
import os
import certifi
from pymongo import MongoClient
from pymongo.server_api import ServerApi
from dotenv import load_dotenv

# Load environment variables from .env file
load_dotenv()

# Get MongoDB credentials from environment variables
MONGO_URI = os.getenv("MONGO_URI")
DB_NAME = os.getenv("MONGO_DB_NAME")
ARTICLES_COLLECTION_NAME = os.getenv("ARTICLES_COLLECTION_NAME")

# Ensure all necessary environment variables are set
if not all([MONGO_URI, DB_NAME, ARTICLES_COLLECTION_NAME]):
    print("❌ Missing required environment variables. Check your .env file.")
    exit()

# Create MongoDB client with TLS verification
try:
    client = MongoClient(MONGO_URI, server_api=ServerApi('1'), tlsCAFile=certifi.where())
    db = client[DB_NAME]
    collection = db[ARTICLES_COLLECTION_NAME]

    # Verify connection
    client.admin.command('ping')
    print("✅ Connected to MongoDB Atlas!")

except Exception as e:
    print(f"❌ MongoDB Connection Error: {e}")
    exit()
# Out:
# Python-dotenv could not parse statement starting at line 1
# Python-dotenv could not parse statement starting at line 2
# Python-dotenv could not parse statement starting at line 3
# Python-dotenv could not parse statement starting at line 4
# Python-dotenv could not parse statement starting at line 5
# Python-dotenv could not parse statement starting at line 6
# Python-dotenv could not parse statement starting at line 7
# ✅ Connected to MongoDB Atlas!

# %%
; MONGO_URI=mongodb+srv://mainamathengej:296ygHRG7TRnmCaW@tuone-cluster.7mato.mongodb.net/?retryWrites=true&w=majority&appName=tuone-cluster
; MONGO_DB_NAME=tuone
; MONGO_ARTICLES_NAME=test_scrape
; ARTICLES_COLLECTION_NAME=test
; MONGO_NODES_NAME=nodes
; MONGO_URLS_NAME=urls
; OPENAI_API_KEY="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"


MONGO_URI=mongodb+srv://greeneconomy:oPHHBBAsFBAPfXyZ@tuone.lgh1dw4.mongodb.net/?retryWrites=true&w=majority&appName=tuone
MONGO_DB_NAME=tuone
ARTICLES_COLLECTION_NAME=articles

# %%
cursor = collection.find({
    "meta.ID": {
        "$exists": True,
        "$type": "string"
    },
    "meta.category": {
        "$exists": False
    }
}).sort("_id", 1)

Sources = {
    11: "electrive",
    12: "energy_voice_hydrogen",
    13: "offshorewind",
    14: "powertechnology",
    15: "pvmagazine",
    16: "pvmagazine",
    17: "pvmagazine",
    18: "pvtech",
    19: "renewsBiz",
    21: "renewsBiz",
    22: "renewsBiz",
    23: "world_energy",
    24: "world_energy",
    25: "world_energy",
    26: "world_energy",
    27: "electrive",
    28: "pvmagazine",
    29: "pvmagazine",
    30: "world_energy",
    31: "world_energy",
    32: "world_energy",
    33: "world_energy",
}

updated_known_count = 0
updated_unknown_count = 0
skipped_count = 0

for doc in cursor:
    try:
        doc_id = doc["_id"]
        meta_id = doc["meta"]["ID"]
        category_key = int(meta_id[:2])
        category_value = Sources.get(category_key, "unknown")

        result = collection.update_one(
            {"_id": doc_id},
            {"$set": {"meta.category": category_value}}
        )

        if result.modified_count > 0:
            if category_value == "unknown":
                updated_unknown_count += 1
                print(f"❓ Set category 'unknown' for doc ID {doc_id} (prefix: {category_key})")
            else:
                updated_known_count += 1
                print(f"✅ Updated doc ID {doc_id} | category: {category_value}")
        else:
            print(f"ℹ️ No changes made for doc ID {doc_id} (already up to date?)")

    except Exception as e:
        print(f"⚠️ Error processing doc ID {doc.get('_id')}: {e}")
        skipped_count += 1

# ---- SUMMARY ----
total_updated_count = updated_known_count + updated_unknown_count

print(f"\n📊 Summary:")
print(f"   ✅ Updated with known category: {updated_known_count}")
print(f"   ❓ Updated with 'unknown': {updated_unknown_count}")
print(f"   📦 Total updated: {total_updated_count}")
print(f"   ⚠️ Skipped due to errors: {skipped_count}")
# Out:
# ✅ Updated doc ID 67fa7e5beaa4fb525afebf7e | category: pvmagazine
# ✅ Updated doc ID 67fa7e5beaa4fb525afebf7f | category: pvmagazine
# ✅ Updated doc ID 67fa7e5ceaa4fb525afebf80 | category: pvmagazine
# ✅ Updated doc ID 67fa7e5ceaa4fb525afebf81 | category: pvmagazine
# ✅ Updated doc ID 67fa7e5ceaa4fb525afebf82 | category: pvmagazine
# ✅ Updated doc ID 67fa7e5ceaa4fb525afebf83 | category: pvmagazine
# ✅ Updated doc ID 67fa7e5deaa4fb525afebf84 | category: pvmagazine
# ✅ Updated doc ID 67fa7e5deaa4fb525afebf85 | category: pvmagazine
# ✅ Updated doc ID 67fa7e5deaa4fb525afebf86 | category: pvmagazine
# ✅ Updated doc ID 67fa7e5deaa4fb525afebf87 | category: pvmagazine
# ✅ Updated doc ID 67fa7e5eeaa4fb525afebf88 | category: pvmagazine
# ✅ Updated doc ID 67fa7e5eeaa4fb525afebf89 | category: pvmagazine
# ✅ Updated doc ID 67fa7e5eeaa4fb525afebf8a | category: pvmagazine
# ✅ Updated doc ID 67fa7e5eeaa4fb525afebf8b | category: pvmagazine
# ✅ Updated doc ID 67fa7e5feaa4fb525afebf8c | category: pvmagazine
# ✅ Updated doc ID 67fa7e5feaa4fb525afebf8d | category: pvmagazine
# ✅ Updated doc ID 67fa7e5feaa4fb525afebf8e | category: pvmagazine
# ✅ Updated doc ID 67fa7e5feaa4fb525afebf8f | category: pvmagazine
# ✅ Updated doc ID 67fa7e60eaa4fb525afebf90 | category: pvmagazine
# ✅ Updated doc ID 67fa7e60eaa4fb525afebf91 | category: pvmagazine
# ✅ Updated doc ID 67fa7e60eaa4fb525afebf92 | category: pvmagazine
# ✅ Updated doc ID 67fa7e60eaa4fb525afebf93 | category: pvmagazine
# ✅ Updated doc ID 67fa7e61eaa4fb525afebf94 | category: pvmagazine
# ✅ Updated doc ID 67fa7e61eaa4fb525afebf95 | category: pvmagazine
# ✅ Updated doc ID 67fa7e61eaa4fb525afebf96 | category: pvmagazine
# ✅ Updated doc ID 67fa7e61eaa4fb525afebf97 | category: pvmagazine
# ✅ Updated doc ID 67fa7e62eaa4fb525afebf98 | category: pvmagazine
# ✅ Updated doc ID 67fa7e62eaa4fb525afebf99 | category: pvmagazine
# ✅ Updated doc ID 67fa7e62eaa4fb525afebf9a | category: pvmagazine
# ✅ Updated doc ID 67fa7e62eaa4fb525afebf9b | category: pvmagazine
# ✅ Updated doc ID 67fa7e62eaa4fb525afebf9c | category: pvmagazine
# ✅ Updated doc ID 67fa7e63eaa4fb525afebf9d | category: pvmagazine
# ✅ Updated doc ID 67fa7e63eaa4fb525afebf9e | category: pvmagazine
# ✅ Updated doc ID 67fa7e63eaa4fb525afebf9f | category: pvmagazine
# ✅ Updated doc ID 67fa7e93eaa4fb525afec067 | category: pvmagazine
# ✅ Updated doc ID 67fa7e93eaa4fb525afec068 | category: pvmagazine
# ✅ Updated doc ID 67fa7e94eaa4fb525afec069 | category: pvmagazine
# ✅ Updated doc ID 67fa7e94eaa4fb525afec06a | category: pvmagazine
# ✅ Updated doc ID 67fa7e94eaa4fb525afec06b | category: pvmagazine
# ✅ Updated doc ID 67fa7e94eaa4fb525afec06c | category: pvmagazine
# ✅ Updated doc ID 67fa7e95eaa4fb525afec06d | category: pvmagazine
# ✅ Updated doc ID 67fa7e95eaa4fb525afec06e | category: pvmagazine
# ✅ Updated doc ID 67fa7e95eaa4fb525afec06f | category: pvmagazine
# ✅ Updated doc ID 67fa7e95eaa4fb525afec070 | category: pvmagazine
# ✅ Updated doc ID 67fa7e95eaa4fb525afec071 | category: pvmagazine
# ✅ Updated doc ID 67fa7e96eaa4fb525afec072 | category: pvmagazine
# ✅ Updated doc ID 67fa7e96eaa4fb525afec073 | category: pvmagazine
# ✅ Updated doc ID 67fa7e96eaa4fb525afec074 | category: pvmagazine
# ✅ Updated doc ID 67fa7e96eaa4fb525afec075 | category: pvmagazine
# ✅ Updated doc ID 67fa7e97eaa4fb525afec076 | category: pvmagazine
# ✅ Updated doc ID 67fa7e97eaa4fb525afec077 | category: pvmagazine
# ✅ Updated doc ID 67fa7e97eaa4fb525afec078 | category: pvmagazine
# ✅ Updated doc ID 67fa7e97eaa4fb525afec079 | category: pvmagazine
# ✅ Updated doc ID 67fa7e98eaa4fb525afec07a | category: pvmagazine
# ✅ Updated doc ID 67fa7e98eaa4fb525afec07b | category: pvmagazine
# ✅ Updated doc ID 67fa7e98eaa4fb525afec07c | category: pvmagazine
# ✅ Updated doc ID 67fa7e98eaa4fb525afec07d | category: pvmagazine
# ✅ Updated doc ID 67fa7e99eaa4fb525afec07e | category: pvmagazine
# ✅ Updated doc ID 67fa7e99eaa4fb525afec07f | category: pvmagazine
# ✅ Updated doc ID 67fa7e99eaa4fb525afec080 | category: pvmagazine
# ✅ Updated doc ID 67fa7e99eaa4fb525afec081 | category: pvmagazine
# ✅ Updated doc ID 67fa7e9aeaa4fb525afec082 | category: pvmagazine
# ✅ Updated doc ID 67fa7e9aeaa4fb525afec083 | category: pvmagazine
# ✅ Updated doc ID 67fa7e9aeaa4fb525afec084 | category: pvmagazine
# ✅ Updated doc ID 67fa7e9aeaa4fb525afec085 | category: pvmagazine
# ✅ Updated doc ID 67fa7e9beaa4fb525afec086 | category: pvmagazine
# ✅ Updated doc ID 67fa7e9beaa4fb525afec087 | category: pvmagazine
# ✅ Updated doc ID 67fa7e9beaa4fb525afec088 | category: pvmagazine
# ✅ Updated doc ID 67fa7e9beaa4fb525afec089 | category: pvmagazine
# ✅ Updated doc ID 67fa7e9beaa4fb525afec08a | category: pvmagazine
# ✅ Updated doc ID 67fa7e9ceaa4fb525afec08b | category: pvmagazine
# ✅ Updated doc ID 67fa7e9ceaa4fb525afec08c | category: pvmagazine
# ✅ Updated doc ID 67fa7e9ceaa4fb525afec08d | category: pvmagazine
# ✅ Updated doc ID 67fa7e9ceaa4fb525afec08e | category: pvmagazine
