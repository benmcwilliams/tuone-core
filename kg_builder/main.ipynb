# %%
from functions import ping_openai, read_prompt_from_file_only, load_function_schema, normalize_id, normalize_type, combine_paragraphs, format_nodes_for_prompt, get_schema, setup_logger
from functions import call_openai_function
from model_dictionary import model_dictionary
from inputs import relationship_groups, groups_to_prompts, nodes_by_group_prompt, characteristic_node_types, required_node_types
from openai_client import openai_client
from mongo_client import mongo_client, articles_collection
from datetime import datetime, timezone

from dotenv import load_dotenv
from bson import json_util
import re
from datetime import datetime, timezone
load_dotenv()

try:
    mongo_client.admin.command("ping")
    print("✅ Connected to MongoDB Atlas!")
except Exception as e:
    print(f"❌ MongoDB Connection Error: {e}")
    raise

# establish openai client 
ping_openai(openai_client)
# Out:
# ✅ Connected to MongoDB Atlas!
# ✅ Successfully connected to OpenAI API!
# Available Models: ['gpt-4o-realtime-preview-2024-12-17', 'gpt-4o-audio-preview-2024-12-17', 'gpt-4-1106-preview', 'dall-e-3', 'dall-e-2', 'gpt-4o-audio-preview-2024-10-01', 'gpt-4-turbo-preview', 'text-embedding-3-small', 'babbage-002', 'gpt-4', 'text-embedding-ada-002', 'chatgpt-4o-latest', 'gpt-4o-mini-audio-preview', 'gpt-4o-audio-preview', 'o1-preview-2024-09-12', 'gpt-4o-mini-realtime-preview', 'gpt-4o-mini-realtime-preview-2024-12-17', 'gpt-4.1-nano', 'gpt-3.5-turbo-instruct-0914', 'gpt-4o-mini-search-preview', 'gpt-4.1-nano-2025-04-14', 'gpt-3.5-turbo-16k', 'gpt-4o-realtime-preview', 'davinci-002', 'gpt-3.5-turbo-1106', 'gpt-4o-search-preview', 'gpt-3.5-turbo-instruct', 'gpt-3.5-turbo', 'o3-mini-2025-01-31', 'gpt-4o-mini-search-preview-2025-03-11', 'gpt-4-0125-preview', 'gpt-4o-2024-11-20', 'gpt-4o-2024-05-13', 'text-embedding-3-large', 'o1-2024-12-17', 'o1', 'o1-preview', 'gpt-4-0613', 'o1-mini', 'gpt-4o-mini-tts', 'o1-pro', 'gpt-4o-transcribe', 'gpt-4.5-preview', 'o1-pro-2025-03-19', 'gpt-4.5-preview-2025-02-27', 'gpt-4o-search-preview-2025-03-11', 'omni-moderation-2024-09-26', 'gpt-image-1', 'o1-mini-2024-09-12', 'tts-1-hd', 'gpt-4o', 'tts-1-hd-1106', 'gpt-4o-2024-08-06', 'gpt-4o-mini-2024-07-18', 'gpt-4.1-mini', 'gpt-4o-mini', 'gpt-4o-mini-audio-preview-2024-12-17', 'gpt-3.5-turbo-0125', 'gpt-4-turbo', 'tts-1', 'gpt-4-turbo-2024-04-09', 'tts-1-1106', 'gpt-4o-realtime-preview-2024-10-01', 'gpt-4o-mini-transcribe', 'gpt-4.1-mini-2025-04-14', 'o3-mini', 'gpt-4.1', 'whisper-1', 'gpt-4.1-2025-04-14', 'omni-moderation-latest', 'o4-mini-2025-04-16', 'o4-mini', 'codex-mini-latest', 'ft:gpt-4o-mini-2024-07-18:personal:capacities:BRLdDiyP:ckpt-step-60', 'ft:gpt-4o-mini-2024-07-18:personal:capacities:BRLdDhGR', 'ft:gpt-4o-mini-2024-07-18:personal:nodes:BRKu8J2E:ckpt-step-246', 'ft:gpt-4o-mini-2024-07-18:personal:financial-origin:BRLnZuG6:ckpt-step-49', 'ft:gpt-4o-mini-2024-07-18:personal:financial-origin:BRLnZeMe:ckpt-step-98', 'ft:gpt-4o-mini-2024-07-18:personal:financial-origin:BRLnaa5P', 'ft:gpt-4o-mini-2024-07-18:personal:financial-technological:BRLwpS2c:ckpt-step-98', 'ft:gpt-4o-mini-2024-07-18:personal:financial-technological:BRLwp6jl', 'ft:gpt-4o-mini-2024-07-18:personal:investments:BRhQzVnK', 'ft:gpt-4o-mini-2024-07-18:personal:investments:BRM8EwB6:ckpt-step-49', 'ft:gpt-4o-mini-2024-07-18:personal:investments:BRM8EOOI:ckpt-step-98', 'ft:gpt-4o-mini-2024-07-18:personal:investments:BRM8EgyY', 'ft:gpt-4o-mini-2024-07-18:personal:nodes:BRKu845w:ckpt-step-123', 'ft:gpt-4o-mini-2024-07-18:personal:nodes:BRKu8Fme', 'ft:gpt-4o-mini-2024-07-18:personal:ownership:BRL9b8QK', 'ft:gpt-4o-mini-2024-07-18:personal:ownership:BRL9aB0O:ckpt-step-123', 'ft:gpt-4o-mini-2024-07-18:personal:ownership:BRL9bz5n:ckpt-step-246', 'ft:gpt-4o-mini-2024-07-18:personal:financial-technological:BRLwoZnv:ckpt-step-49', 'ft:gpt-4o-mini-2024-07-18:personal:technological:BRLQoPDs:ckpt-step-123', 'ft:gpt-4o-mini-2024-07-18:personal:technological:BRLQp9Wj:ckpt-step-246', 'ft:gpt-4o-mini-2024-07-18:personal:investments:BRhQyouD:ckpt-step-50', 'ft:gpt-4o-mini-2024-07-18:personal:technological:BRLQpixd', 'ft:gpt-4o-mini-2024-07-18:personal:investments:BRhQzcVb:ckpt-step-100', 'ft:gpt-4o-mini-2024-07-18:personal:capacities:BRLdDVWD:ckpt-step-120', 'ft:gpt-4o-mini-2024-07-18:personal:ownership:BXWPFhyU:ckpt-step-165', 'ft:gpt-4o-mini-2024-07-18:personal:ownership:BXWPFMoh:ckpt-step-330', 'ft:gpt-4o-mini-2024-07-18:personal:ownership:BXWPGQJN', 'ft:gpt-4o-mini-2024-07-18:personal:capacities:BXXsRJtj:ckpt-step-74', 'ft:gpt-4o-mini-2024-07-18:personal:capacities:BXXsRSkB:ckpt-step-148', 'ft:gpt-4o-mini-2024-07-18:personal:capacities:BXXsRMI4', 'ft:gpt-4o-mini-2024-07-18:personal:financial-technological:BXXZRRj2:ckpt-step-62', 'ft:gpt-4o-mini-2024-07-18:personal:technological:BXWs5Zte:ckpt-step-164', 'ft:gpt-4o-mini-2024-07-18:personal:investments:BXY0ZQST:ckpt-step-62', 'ft:gpt-4o-mini-2024-07-18:personal:investments:BXY0ZiyQ:ckpt-step-124', 'ft:gpt-4o-mini-2024-0 ...

# %%
def extract_nodes(article_id, text, model_name, logger):

    PROMPT_PATH = "prompts/entities-only.txt"
    FUNCTION_SCHEMA_PATH = "schemas/entities.json"

    function_schema = load_function_schema(FUNCTION_SCHEMA_PATH)
    prompt = read_prompt_from_file_only(PROMPT_PATH)

    user_content = f"Here is the article: {text}"

    nodes_by_category = call_openai_function(
        prompt=prompt,
        user_content=user_content,
        function_schema=function_schema,
        function_name="extract_clean_tech_entities",
        expected_top_key="nodes",
        model_name=model_name,
        logger=logger
    )

    # Flatten nodes while retaining their type
    formatted_nodes = []
    for node_type, node_categories in nodes_by_category.items():
        for node in node_categories:
            formatted_node = {
                "article_id": article_id,
                "id": normalize_id(node.get("id")),
                "type": normalize_type(node.get("type")),
                "name": node.get("name"),
                "location": {
                    "city": node.get("location", {}).get("city", ""),
                    "country": node.get("location", {}).get("country", "")
                } if node.get("location") else None,
                "amount": node.get("amount"), #possibly to drop
                "status": node.get("status"),
            }
            formatted_nodes.append(formatted_node)

    return formatted_nodes

# %%
def extract_node_characteristics(text, nodes, relationship_group, model_name, logger):

    PROMPT_PATH = groups_to_prompts[relationship_group]
    FUNCTION_SCHEMA_PATH = f"schemas/{relationship_group}.json"

    prompt = read_prompt_from_file_only(PROMPT_PATH)
    function_schema = load_function_schema(FUNCTION_SCHEMA_PATH)

    allowed_types = nodes_by_group_prompt[relationship_group]
    compact_nodes = format_nodes_for_prompt(nodes, allowed_types)
    
    user_content = f"""Here is the article text: {text}
    Here is the list of known entities:
    {compact_nodes}
    """

    return call_openai_function(
        prompt=prompt,
        user_content=user_content,
        function_schema=function_schema,
        function_name="extract_characteristics",
        expected_top_key="node_characteristics",
        model_name=model_name,
        logger=logger
    )

# %%
def extract_relationships(article_id, text, nodes, relationship_group, model_name, logger, allowed_types=None):

    PROMPT_PATH = groups_to_prompts[relationship_group]
    FUNCTION_SCHEMA_PATH = f"schemas/{relationship_group}.json"

    prompt = read_prompt_from_file_only(PROMPT_PATH)
    function_schema = load_function_schema(FUNCTION_SCHEMA_PATH)

    allowed_types = nodes_by_group_prompt[relationship_group]
    compact_nodes = format_nodes_for_prompt(nodes, allowed_types)

    user_content = f"""Here is the article text: {text}
    Here is the list of known entities:
    {compact_nodes}
    Please extract only the specified relationship types.
    """

    # Use shared OpenAI wrapper
    raw_relationships = call_openai_function(
        prompt=prompt,
        user_content=user_content,
        function_schema=function_schema,
        function_name="extract_clean_tech_relationships",
        expected_top_key="relationships",
        model_name=model_name,
        logger=logger
    )

    # Format output
    formatted_relationships = []
    for rel in raw_relationships:
        raw_source = rel.get("source")
        raw_target = rel.get("target")
        norm_source = normalize_id(raw_source)
        norm_target = normalize_id(raw_target)

        formatted_relationships.append({
            "article_id": article_id,
            "id": f"{norm_source}_{rel.get('type')}_{norm_target}",
            "source": norm_source,
            "target": norm_target,
            "type": rel.get("type"),
            "group": relationship_group
        })

    return formatted_relationships

# %%
def should_skip_article(article, logger, run_id):
    """Returns (proceed, text). If should skip, returns (False, None)."""

    # skip if article has been validated
    val = article.get("validation")
    if val is True:
        print("⏭️  Skipping – article is validated")
        logger.info("⏭️  Skipping – article is validated")
        return False, None

    if isinstance(val, (int, float)):
        processed_on = datetime.fromtimestamp(val, tz=timezone.utc)\
                               .strftime("%Y-%m-%d %H:%M UTC")
        print(f"⏭️  Skipping – article was validated on {processed_on}")
        logger.info("⏭️  Skipping – article was validated on %s", processed_on)
        return False, None
    
    # skip if this model architecture has already processed article
    previous_run = article.get("llm_processed", {}).get("run_id")
    if previous_run == run_id:
        print(f"⏭️  Skipping – article already processed with run_id: {run_id}")
        logger.info(f"⏭️  Skipping – article already processed with run_id: {run_id}")
        return False, None

    # skip if there is no text
    text = combine_paragraphs(article)
    if not text:
        logger.warning("⚠️ No valid text found; skipping.")
        return False, None

    return True, text

def process_articles(articles_to_process, model_dictionary):

    run_id = model_dictionary["run_id"]
    for article in articles_to_process:
        articleID  = str(article["_id"])
        friendly_id = article["meta"]["ID"]
        logger      = setup_logger(friendly_id)

        print(f"📌 Processing Article: {article['title']}")
        logger.info("📌 Processing Article ID: %s — %s", friendly_id, article["title"])

        proceed, text = should_skip_article(article, logger, run_id)
        if not proceed:
            continue

        try:
            # extract entities
            formatted_nodes = extract_nodes(articleID, text, model_dictionary["nodes"], logger)
            logger.info(f"Formatted nodes used for all prompts hereafter: {formatted_nodes}")

            # attach characteristics to entities (capacities and investments)
            for relationship_group, config in characteristic_node_types.items():
                model_name = model_dictionary[relationship_group] # select fine-tuned model
                id_key = config["id_key"]
                type_match = config["type_match"]

                # only continue if there are nodes of this type in the article
                has_relevant_nodes = any(node.get("type") == type_match for node in formatted_nodes)
                if not has_relevant_nodes:
                    logger.info(f"⏭️ Skipping {relationship_group} – no nodes of type '{type_match}' found.")
                    continue

                logger.info(f"🔍 Extracting characteristics for node group: {relationship_group}")
                node_characteristics = extract_node_characteristics(text, formatted_nodes, relationship_group, model_name, logger)  

                # attach 'status' and 'type' to matching capacity nodes (flat list structure)
                for char in node_characteristics:
                    node_id = char.get(id_key)
                    logger.info(f"Node ID is {node_id}")
                    found_match = False

                    for node in formatted_nodes:
                        if node.get("id") == node_id and node.get("type") == type_match:
                            logger.info(f"✅ Match found for {id_key} '{node_id}' in {type_match} nodes")
                            if "status" in char:
                                node["status"] = char["status"]
                                logger.info(f"  ➕ Set status: {char['status']}")
                            if "phase" in char:
                                node["phase"] = char["phase"]
                                logger.info(f"  ➕ Set phase: {char['phase']}")
                            found_match = True

                    if not found_match:
                        logger.info(f"⚠️ No match found for {id_key} '{node_id}' in formatted_nodes")

            # extract relationships between entities
            all_relationships = []
            for relationship_group,model_name in model_dictionary.items():
                if relationship_group in ["nodes", "capacities", "investments"]: #skip nodes, capacities and investments which have logic elsewhere
                    continue

                def has_required_nodes(formatted_nodes, required_types):
                    existing_types = {node['type'] for node in formatted_nodes}
                    return any(req_type in existing_types for req_type in required_types)
                
                required_types = required_node_types.get(relationship_group, [])
                if not has_required_nodes(formatted_nodes, required_types):
                    logger.info(f"🛑 Skipping {relationship_group}: required nodes {required_types} not present.")
                    continue

                logger.info(f"- - - Querying openai for relationships: {relationship_group}, using model: {model_name}")

                allowed_types = relationship_groups[relationship_group]
                logger.info(f"Node types included in the query: {allowed_types}")

                relationships = extract_relationships(articleID, text, formatted_nodes, relationship_group, model_name, logger, allowed_types)
                all_relationships.extend(relationships)

            # update entries in mongodb with clean entities and relationships
            update_result = articles_collection.update_one(
                {"_id": article["_id"]},  #match by article id
                {"$set": {
                    "nodes": formatted_nodes or [],
                    "relationships": all_relationships or [],
                    "llm_processed.run_id": model_dictionary["run_id"],
                    "llm_processed.ts": datetime.now(timezone.utc).isoformat()
                    }})

            if update_result.modified_count > 0:
                logger.info(f"✅ Updated Article ID: {articleID} with {len(formatted_nodes)} nodes and combined text.")
            else:
                logger.info(f"⚠️ No updates made for Article ID: {articleID}.")

        except Exception as e:
            print(f"❌ Error processing Article ID {articleID}: {e}")

# %%
n_articles = 3000
offset_articles = 0

articles_to_process = list(
    articles_collection.find(
        {"meta.ID": {"$regex": "^11"}},  
        {"_id": 1, "meta": 1, "title": 1, "validation": 1, "llm_processed": 1,  "paragraphs": 1}       
    )
    .sort("_id", -1)            # sort by MongoDB ObjectId (descending)
    .skip(offset_articles)      # skip first `offset` articles
    .limit(n_articles)          # limit the number of articles
)

process_articles(articles_to_process, model_dictionary)
# Out:
# 📌 Processing Article: Volkswagen to cut battery production plans in Salzgitter
# ⏭️  Skipping – article is validated
# 📌 Processing Article: Mazda to build battery module plant in Iwakuni
# ⏭️  Skipping – article is validated
# 📌 Processing Article: Sony-Honda alliance prices electric saloon Afeela 1 at $90,000
# 📌 Processing Article: Kia EV3 likely will arrive sooner, EV4 delayed
# ⏭️  Skipping – article is validated
# 📌 Processing Article: USA changes EV tax credit list: Hyundai is in, VW is out
# 📌 Processing Article: Hyundai close to starting solid-state battery pilot production
# 📌 Processing Article: Northvolt owners vote in favour of restructuring
# ⏭️  Skipping – article is validated
# 📌 Processing Article: Lucid Gravity uses 2170 cells from Panasonic
# ⏭️  Skipping – article is validated
# 📌 Processing Article: Manz is up for sale
# ⏭️  Skipping – article is validated
# 📌 Processing Article: Nova Bus teams up with Lithion for battery recycling
# ⏭️  Skipping – article is validated
# 📌 Processing Article: Novonix receives conditional loan commitment in the US
# ⏭️  Skipping – article already processed with run_id: v0
# 📌 Processing Article: Porsche seals investment in Varta subsidiary V4Drive
# 📌 Processing Article: BMW to open battery cell recycling centre in Bavaria
# 📌 Processing Article: Funding for battery recycling plant from ABTC
# 📌 Processing Article: BTR plans to produce anode materials in Morocco
# 📌 Processing Article: Ford pauses construction of Canadian cathode material plant again
# 📌 Processing Article: Forsee Power inaugurates factory in Ohio
# 📌 Processing Article: Moment Energy to construct EV battery reuse Gigafactory in Texas
# 📌 Processing Article: LG Energy Solution and Rivian announce battery deal
# 📌 Processing Article: Northvolt likely to receive bridging aid
# 📌 Processing Article: CATL offers innovation financing to its suppliers
# 📌 Processing Article: Stellantis & CATL officially confirm LFP battery cells plant in Spain
# 📌 Processing Article: Tesla is likely planning four versions of the 4680 battery cells
# 📌 Processing Article: General Motors founds joint venture for lithium production
# 📌 Processing Article: Factorial presents 40 Ah solid-state battery cells with dry cathodes
# 📌 Processing Article: Sunwoda to improve solid-state battery prototypes with XTC
# 📌 Processing Article: Funding for battery recycling plant from ABTC
# 📌 Processing Article: Cornish Lithium opens demonstration plant in Cornwall
# 📌 Processing Article: VinFast starts delivering the VF 9 in the US
# 📌 Processing Article: MAN Engines introduces a new innovative energy storage solution
# 📌 Processing Article: Northvolt refocuses scope of activities and cuts jobs
# 📌 Processing Article: Galp scraps plans for lithium plant in Portugal following Northvolt exit
# 📌 Processing Article: Panasonic is ready for series production of 4680 cells
# 📌 Processing Article: Hyundai factory in Georgia faces renewed scrutiny over water supply
# 📌 Processing Article: McGill University find improvements for solid-state battery electrodes
# 📌 Processing Article: Northvolt factory in Canada could be delayed until 2028
# 📌 Processing Article: Battery recycling: Plans for Indo-American joint venture
# 📌 Processing Article: Spain subsidises Stellantis and PowerCo battery plants
# 📌 Processing Article: Scania starts looking for alternatives to Northvolt
# 📌 Processing Article: BMW launches operation of battery test centre in Wackersdorf
# 📌 Processing Article: Indonesia apparently supplies nickel battery material to Tesla
# 📌 Processing Article: Made in the USA: Ascend ready to supply lithium carbonate from recycled batteries
# 📌 Processing Article: QuantumScape completes production process for solid-state cells
# 📌 Processing Article: Electrode start-up Anaphite raises 12.5 million euros
# 📌 Processing Article: Northvolt appoints restructuring manager for its battery factory
# 📌 Processing Article: Cylib starts building battery recycling plant in Germany
# 📌 Processing Article: Battery cell developer 24M opens pilot plant in Thailand
# 📌 Processing Article: Electra receives $20 million in US government funding
# 📌 Processing Article: Northvolt holds onto prospect of short-term financial boost of $300 million
# 📌 Processing Article: Freyr Battery expects €122 million grant from the EU
# 📌 Processing Article: Lyten acquires facilities from Northvolt subsidiary Cuberg
# 📌 Processing Article: Italy withdraws funding commitment for ACC cell plant in Termoli
# 📌 Processing Article: Vianode opens graphite production plant in Norway
# 📌 Processing Article: GM and Samsung SDI to open US cell plant in 2027
# 📌 Processing Article: Stellantis and Orano call off recycling joint venture
# 📌 Processing Article: VW acquires stake in Canadian lithium company for PowerCo
# 📌 Processing Article: Vulcan produces first lithium hydroxide in Germany
# 📌 Processing Article: VW & Stellantis sign graphite supply deal with Novonix
# 📌 Processing Article: CATL positions itself for cell production in Indonesia
# 📌 Processing Article: EMR opens EV battery recycling facility in Birmingham
# 📌 Processing Article: Xing Mobility to show immersion-cooled Cell-to-Chassis battery
# 📌 Processing Article: SVOLT confirms cancellation of its Saarland plans
# 📌 Processing Article: Webasto uses second-life battery storage at its Schierling plant
# 📌 Processing Article: Lyten to build Gigafactory in Nevada
# 📌 Processing Article: Volvo Cars wants to take over Northvolt joint venture
# 📌 Processing Article: E-Lyte opens electrolyte plant in Kaiserslautern
# 📌 Processing Article: AVL equips PowerCo’s battery testing laboratory
# 📌 Processing Article: Audi builds battery assembly plant in Mexico
# 📌 Processing Article: EU project to establish digital battery passport
# 📌 Processing Article: Northvolt cuts 1,600 jobs, puts cell plant expansion on ice
# 📌 Processing Article: CATL considers building battery plant in the USA
# 📌 Processing Article: Will a consortium of investors support Northvolt?
# 📌 Processing Article: Battery chemicals manufacturer Terrafame announces job cuts
# 📌 Processing Article: NextStar Energy kicks off battery module production
# 📌 Processing Article: Dodge Charger Daytona receives solid-state battery for demo purposes
# 📌 Processing Article: GM & CATL in talks regarding joint battery factory
# 📌 Processing Article: Gotion approves billion-euro investment for cell plants in Slovakia and Morocco
# 📌 Processing Article: Ioneer wants to build lithium mine in Nevada
# 📌 Processing Article: India’s Ola Electric to sell e-2Ws with 4680 cells from 2025
# 📌 Processing Article: UL Solutions opens battery lab in Michigan
# 📌 Processing Article: Fraunhofer ISE opens battery research centre in Freiburg
# 📌 Processing Article: LEAD Chairman Yanqing Wang provides insight behind the scenes of battery production
# 📌 Processing Article: Manz files for insolvency
# 📌 Processing Article: AMG Lithium opens first lithium refinery in Europe
# 📌 Processing Article: CATL denies rumours regarding Northvolt investment
# 📌 Processing Article: LG Chem to supply cathode active materials to PPES in Japan
# 📌 Processing Article: Eramet and Suez suspend plans for battery recycling in France
# 📌 Processing Article: Circu Li-On looks in on Amazon processes
# 📌 Processing Article: SK On orders lithium from Posco
# 📌 Processing Article: VW and Goldman Sachs write off Northvolt shares
# 📌 Processing Article: LGES plans dry electrode pilot line before the end of 2024
# 📌 Processing Article: Northvolt’s Swedish battery plant-expansion company files for bankruptcy
# 📌 Processing Article: GM will sell its battery cell plant to LG Energy Solution
# 📌 Processing Article: Akasol to produce batteries for electric utility vehicles
# 📌 Processing Article: BLC puts fully automated battery discharge system into operation
# 📌 Processing Article: LG Energy Solution to supply batteries for Ford vans in Europe
# 📌 Processing Article: Norge Mining to take over Europe’s largest graphite mine
# 📌 Processing Article: Italy attempts to push Stellantis to commit to ACC cell factory
# 📌 Processing Article: Anthro gears up to construct an electrolyte production facility with a robust grant
# 📌 Processing Article: LG Chem wants to buy US lithium from ExxonMobil
# 📌 Processing Article: Altilium recycles cathode active material without compromising on quality
# 📌 Processing Article: Groundbreaking ceremony for Asahi Kasei’s battery separator plant in Canada
# 📌 Processing Article: Samsung SDI selects battery material supplier in the USA
# 📌 Processing Article: OCSiAl to supply ProLogium with carbon nanotubes for solid-state batteries
# 📌 Processing Article: Topping-Out ceremony for MAN’s new battery production facility in Nuremberg
# 📌 Processing Article: Morrow Batteries opens Gigafactory in southern Norway
# 📌 Processing Article: Mercedes-Benz opens battery recycling factory in Germany
# 📌 Processing Article: AE Elemental opens recycling plant in Poland
# 📌 Processing Article: Dürr presents improved system for electrode coating
# 📌 Processing Article: Argentina: Rio Tinto invests to expand Rincon project
# 📌 Processing Article: Echion and CBMM open a facility to mass-produce XNO
# 📌 Processing Article: TU Freiberg tests new shredder plant for battery recycling
# 📌 Processing Article: Northvolt files for Chapter 11 in the US
# 📌 Processing Article: Honda opens pilot production line for solid-state batteries
# 📌 Processing Article: Jaguar Land Rover to test Altilium batteries with recycled materials
# 📌 Processing Article: Ganfeng Lithium wants to build batteries in Turkey
# 📌 Processing Article: Geothermal cooperation: BASF flirts with geothermal energy, Vulcan with lithium plant
# 📌 Processing Article: Altilium starts recycling battery waste in Plymouth
# 📌 Processing Article: Japanese offensive in battery production
# 📌 Processing Article: Hyundai partners with Canadian battery recycler Lithion
# 📌 Processing Article: BlueOval SK secures US loan to construct battery plants
# 📌 Processing Article: StarPlus Energy receives conditional commitment for billion-dollar loan
# 📌 Processing Article: Battery recycling project spins off from University of Graz
# 📌 Processing Article: Valmet Automotive spins off battery business
# 📌 Processing Article: Ford to build battery assembly plant in Romania
# 📌 Processing Article: Germany’s battery researchers fear a complete funding freeze
# 📌 Processing Article: LG & JSW in talks for a battery gigafactory in India
# 📌 Processing Article: Li-Cycle receives $475 million government loan for battery recycling plant
# 📌 Processing Article: ICPT starts automated production of batteries for electric trucks and buses
# 📌 Processing Article: Sakuu and Eleqtrion to advance aluminium ion battery technology
# 📌 Processing Article: SVOLT considers dropping plans for Saarland plants
# 📌 Processing Article: CATL considers recycling factory in Europe
# 📌 Processing Article: Group14 kicks off silicon carbon anode material production in South Korea
# 📌 Processing Article: KIT opens world’s first ‘agile’ battery cell production facility
# 📌 Processing Article: Asahi Kasei and Honda Motor sign a joint partnership to produce lithium-ion battery separators
# 📌 Processing Article: Fortum faces resistance on planned recycling factory in Germany
# 📌 Processing Article: Hyundai and LGES inaugurate Indonesia’s first cell factory
# 📌 Processing Article: Rock Tech loses funding support from Germany
# 📌 Processing Article: Porsche hesitates to build a battery factory in Brandenburg
# 📌 Processing Article: Panasonic curbs plans for expanded US cell production
# 📌 Processing Article: 3D-printed solid-state batteries: SK On cooperates with US developer Sakuu
# 📌 Processing Article: Renault embraces LFP batteries
# 📌 Processing Article: Panasonic opens new battery development centre in Japan
# 📌 Processing Article: Nio produces battery packs with semi-solid-state cells in series
# 📌 Processing Article: Daimler Truck, PACCAR, and Accelera complete battery cell JV formation
# 📌 Processing Article: Amplify starts construction of battery cell factory
# 📌 Processing Article: Factorial delivers B-samples of its solid-state cells to Mercedes
# 📌 Processing Article: LG Energy Solution is on track with Arizona battery factory
# 📌 Processing Article: AESC to expand battery factory in South Carolina
# 📌 Processing Article: Plans for Gotion’s battery factory in Morocco take shape
# 📌 Processing Article: Chinese startup achieves 120 Ah solid-state cell
# 📌 Processing Article: BTR kicks off anode material production in Indonesia
# 📌 Processing Article: Ascend Elements starts operations in Poland via joint venture
# 📌 Processing Article: LG Energy Solution to supply Tesla with electrodes worth billions
# 📌 Processing Article: FFB launches cooperation with PEM Motion
# 📌 Processing Article: Stena Recycling to open battery value chain hub in Norway
# 📌 Processing Article: Nissan wants to build first solid-state battery cells in 2025
# 📌 Processing Article: Britishvolt’s planned cell factory likely to face final curtain
# 📌 Processing Article: DHL Group EV Center of Excellence opened in Italy
# 📌 Processing Article: Forge Nano to deliver first battery cell samples this year
# 📌 Processing Article: Altilium & Enva announce battery recycling cooperation in the UK
# 📌 Processing Article: LGES to establish factory for LFP batteries for Europe
# 📌 Processing Article: VW certifies CATL battery test centre in Erfurt
# 📌 Processing Article: Grosse Lembeck to head battery recycling at BASF
# 📌 Processing Article: SK On sign lithium supply deal with ExxonMobil
# 📌 Processing Article: ElringKlinger to open battery factory in South Carolina
# 📌 Processing Article: Northvolt appoints new CFO
# 📌 Processing Article: Ferrari expands battery partnership with SK On
# 📌 Processing Article: EnBW and LevertonHELM produce high-purity lithium carbonate
# 📌 Processing Article: Daimler Buses switches battery partner to BMZ Poland
# 📌 Processing Article: BASF puts plans for cathode material factory in Finland on hold
# 📌 Processing Article: Korean researchers are fine-tuning a hybrid sodium-ion battery
# 📌 Processing Article: InoBat starts battery cell production in Slovakia
# 📌 Processing Article: Volkswagen Truck & Bus tests electric bus with ultra-fast charging battery in Brazil
# 📌 Processing Article: Gotion High-Tech to build fast-charging 5C battery in series production
# 📌 Processing Article: VW allegedly sets up task force on Northvolt problems
# 📌 Processing Article: Northvolt likely losing billion-euro order from BMW
# 📌 Processing Article: BMW kicks off construction work at the battery assembly plant in Straßkirchen
# 📌 Processing Article: New eCampus: Mercedes bundles battery development in Stuttgart
# 📌 Processing Article: LGES and Posco reduce battery investments
# 📌 Processing Article: Porsche considers acquiring a stake in Varta battery subsidiary V4Drive
# 📌 Processing Article: Daimler Truck opens Battery Technology Centre
# 📌 Processing Article: The Mobility House and GESI plan large-scale storage from electric car batteries
# 📌 Processing Article: TU Graz receives funding for battery research centre
# 📌 Processing Article: CATL and Tesla launch cooperation to optimise charging times
# 📌 Processing Article: Ascend Elements supplies recycled cathode material to Freudenberg
# 📌 Processing Article: LiNa Energy successfully closes funding round
# 📌 Processing Article: Did Ultium Cells halt construction of its third battery factory?
# 📌 Processing Article: CATL, BAIC & Xiaomi break ground on battery cell plant in Beijing
# 📌 Processing Article: Trumpf presents laser system for battery recycling
# 📌 Processing Article: Customcells purchases silicon anode material from Group14
# 📌 Processing Article: ACC puts work on battery factories in Kaiserslautern and Termoli on hold
# 📌 Processing Article: Stellantis develops battery cells for cheaper electric cars with CEA
# 📌 Processing Article: Onsemi presents new generation of SiC semiconductors
# 📌 Processing Article: German battery recyclers RET and Tozero join forces
# 📌 Processing Article: Ultium Cells delivers first battery cells from Tennessee factory
# 📌 Processing Article: Rock Tech Lithium receives green light to build refinery in Guben
# 📌 Processing Article: Eve Energy presents cylindrical cells with 6C charge rate
# 📌 Processing Article: Battery cell production research: FFB PreFab opens in Münster
# 📌 Processing Article: Technotrans receives major order for electric bus battery management systems
# 📌 Processing Article: Webasto expands battery production in South Korea
# 📌 Processing Article: Northvolt breaks ground for German battery factory
# 📌 Processing Article: Varta initiates project to develop sodium-ion batteries
# 📌 Processing Article: Fenecon opens factory for second-life battery storage systems
# 📌 Processing Article: Sila raises $375 million for silicon anode production
# 📌 Processing Article: Tesla has produced sufficient batteries for 1,000 Cybertrucks
# 📌 Processing Article: Lithium producer Vulcan Energy brings on ABB as production partner
# 📌 Processing Article: BASF opens prototype metal refinery for battery recycling
# 📌 Processing Article: Norway supports Vianode’s anode material factory
# 📌 Processing Article: BASF pauses construction of battery recycling plant in Spain
# 📌 Processing Article: StoreDot opens new US HQ in California
# 📌 Processing Article: ZSW supplies cathode material for tests
# 📌 Processing Article: Gotion and InoBat confirm gigafactory in Slovakia
# 📌 Processing Article: SAIC to supply IM Motors EVs with solid-state batteries
# 📌 Processing Article: Lyten delivers first lithium-sulphur battery cells to customers
# 📌 Processing Article: New player: Prime Lithium wants to produce lithium for EVs in Germany
# 📌 Processing Article: Toyota to build a new EV battery plant in Japan
# 📌 Processing Article: Vulcan Energy extracts first lithium chloride in new factory
# 📌 Processing Article: Envirostream signs deals with LG Energy and Hyundai Glovis
# 📌 Processing Article: Northvolt reconsiders expansion plans
# 📌 Processing Article: Graphjet to build graphite plant in Nevada
# 📌 Processing Article: Echion raises $35 million to manufacture XNO anode material
# 📌 Processing Article: Ascend Elements & Call2Recycle launch collaboration in the US
# 📌 Processing Article: Umicore stops construction of its cathode material factory in Canada
# 📌 Processing Article: RWTH Chair of PEM cooperates with Chinese plant manufacturer HYNN
# 📌 Processing Article: Farasis and FAW join forces on commercial vehicle batteries
# 📌 Processing Article: Asahi Kasei to build battery separator plant in Canada
# 📌 Processing Article: Tritium to be acquired by Exicom
# 📌 Processing Article: Rock Tech’s German lithium plant receives funding from Brandenburg
# 📌 Processing Article: Eve Energy considers building battery factory in Coventry
# 📌 Processing Article: Hyundai Mobis starts building battery plant for VW in Spain
# 📌 Processing Article: Verkor secures billion euro loan to complete cell factory
# 📌 Processing Article: Nissan and SK On are planning a US battery factory
# 📌 Processing Article: BYD & Huaihai launch joint venture for sodium-ion batteries
# 📌 Processing Article: SVOLT will not build battery factory in Germany
# 📌 Processing Article: Liberec to build largest-yet EV battery recycling factory in Switzerland
# 📌 Processing Article: BMW receives planning permission for battery assembly plant
# 📌 Processing Article: EMR & Renewable Metals to build pilot recycling plant in
# 📌 Processing Article: LGES purchases more lithium from Liontown Resources
# 📌 Processing Article: REWIND consortium researches the direct recycling of batteries
# 📌 Processing Article: Tesla allegedly plans 4680 cells with dry coating in 2024
# 📌 Processing Article: Budding battery recycler Cylib raises 55 million euros
# 📌 Processing Article: Traton could build a third assembly plant for truck batteries
# 📌 Processing Article: Ecopro to produce cathode material for sodium-ion batteries
# 📌 Processing Article: Volvo pioneers Battery Passport
# 📌 Processing Article: Volvo and CATL launch recycling cooperation in China
# 📌 Processing Article: US DOE could help finance Entek’s separator manufacturing plans
# 📌 Processing Article: Swiss battery specialist 8inks raises three million euros
# 📌 Processing Article: Redwood Materials to recycle Ultium Cells’ production waste
# 📌 Processing Article: “What supply chain strategies look like” – interview with Grant Ray from Group14
# 📌 Processing Article: CATL gears up for next-gen SIBs and global licensing
# 📌 Processing Article: Dürr, Grob and Manz present battery concept factory
# 📌 Processing Article: Honda to build EVs and batteries in Canada
# 📌 Processing Article: Eramet inaugurates lithium extraction plant in Argentina
# 📌 Processing Article: Group14 announces multiple major battery orders
# 📌 Processing Article: Testing the BMW iX5 Hydrogen: It works – but is it convincing?
# 📌 Processing Article: Altilium & Connected Energy announce battery recycling cooperation
# 📌 Processing Article: PowerCo: VW battery production on schedule
# 📌 Processing Article: BASF & Emaret cancel plans for nickel-cobalt refinery in Indonesia
# 📌 Processing Article: Tozero delivers first batch of recycled lithium
# 📌 Processing Article: Lucid to source anode material from Graphite One
# 📌 Processing Article: Factorial Energy and LG Chem forge solid-state battery alliance
# 📌 Processing Article: CATL and GM could build LFP battery factory in North America
# 📌 Processing Article: Jaguar ups planned spending as it continues to invest in combustion engines
# 📌 Processing Article: Vitesco implements Kyburz’ battery recycling process
# 📌 Processing Article: WHW Recycling & BASF join forces on battery recycling in Germany.
# 📌 Processing Article: Mercedes cuts production of the S-Class & EQS
# 📌 Processing Article: Porsche considers an investment in Varta
# 📌 Processing Article: CATL to focus on international expansion
# 📌 Processing Article: Porsche employs used Taycan batteries for stationary energy storage
# 📌 Processing Article: Hydrovolt expands battery recycling operations to France
# 📌 Processing Article: Honda to build EV and battery factories in Canada
# 📌 Processing Article: Samsung SDI to start mass production of solid-state batteries in 2027
# 📌 Processing Article: Panasonic could add 4680 production to new Kansas plant
# 📌 Processing Article: Swobbee puts four battery swap stations into operation in New York
# 📌 Processing Article: Kia and Tesla could produce EVs in Thailand
# 📌 Processing Article: UK government supports EV battery development centre
# 📌 Processing Article: LG Energy Solution launches scooter battery swapping network with Kooroo
# 📌 Processing Article: Customcells founds US subsidiary and opens office in Detroit
# 📌 Processing Article: BMW starts building battery assembly plant in Thailand
# 📌 Processing Article: ‘BATTwin’ research project on sustainable battery production
# 📌 Processing Article: Glencore fills financing gap for battery recycling partner Li-Cycle
# 📌 Processing Article: BYD expands e-bus business in North America
# 📌 Processing Article: Toyota tackles takeover of battery subsidiary Primearth EV Energy
# 📌 Processing Article: SK Innovation plans battery production in Hungary
# 📌 Processing Article: BAIC, CATL & Xiaomi to build battery cell factory in Beijing
# 📌 Processing Article: SQM Lithium Ventures increases investment in Altilium
# 📌 Processing Article: Batteries: What will the EU’s Critical Raw Materials Act really achieve?
# 📌 Processing Article: Canada subsidises Electra Battery Materials’ cobalt sulphate refinery
# 📌 Processing Article: German battery research production to focus on solid-state technology
# 📌 Processing Article: German start-ups launch battery recycling cooperation
# 📌 Processing Article: BYD starts building sodium battery plant in China
# 📌 Processing Article: Stena recycles production scrap from Morrow Batteries
# 📌 Processing Article: Hyundai applies for patent for solid-state battery system
# 📌 Processing Article: Tiamat to build a 5 GWh factory for sodium-ion batteries in France
# 📌 Processing Article: Panasonic plans to improve Tesla cells
# 📌 Processing Article: Over €4 billion secured for European battery production
# 📌 Processing Article: Lanxess and IBU-Tec are working on better iron oxides for LFP batteries
# 📌 Processing Article: EU approves major German subsidy for Northvolt battery factory
# 📌 Processing Article: Tata to build battery factory in Somerset
# 📌 Processing Article: Daimler Truck selects Mississippi site for new battery factory
# 📌 Processing Article: SK On and six partners to make battery production smarter
# 📌 Processing Article: Ecopro to source recycled materials from Cirba for new cathodes
# 📌 Processing Article: LGES to launch 4680 series production in August
# 📌 Processing Article: Zeekr presents LFP battery with fast charging rate
# 📌 Processing Article: Northvolt secures new billion-dollar loan
# 📌 Processing Article: Panasonic orders more battery can production lines from H&T
# 📌 Processing Article: Redwood Materials breaks ground on new battery factory
# 📌 Processing Article: Customcells to manufacture battery cells from US startup Enevate
# 📌 Processing Article: Isuzu is making massive investments in electric vehicles
# 📌 Processing Article: 24M presents innovative battery separator
# 📌 Processing Article: UKIB boosts the second British battery factory by AESC
# 📌 Processing Article: InoBat begins making battery cells in Slovakia
# 📌 Processing Article: Honda could soon make EVs and batteries in Canada
# 📌 Processing Article: Varta to bundle research & development in Graz
# 📌 Processing Article: CATL to build battery plant in Beijing
# 📌 Processing Article: BYD & FAW launch series production of blade battery in Changchun
# 📌 Processing Article: Iveco chooses BASF as recycling partner for commercial vehicle batteries
# 📌 Processing Article: Tesla’s 4680 cells production is no longer a bottleneck
# 📌 Processing Article: Battery factories: Europe’s mechanical engineering companies are lagging behind
# 📌 Processing Article: NMG strikes major deals to push graphite extraction for Panasonic and GM
# 📌 Processing Article: LGES purchases LFP cathode materials in China
# 📌 Processing Article: LG Chem commences construction of mega CAM factory in Tennessee
# 📌 Processing Article: Nissan wants to reduce manufacturing costs for LFP batteries
# 📌 Processing Article: Customcells inaugurates new headquarters in Itzehoe
# 📌 Processing Article: LG Energy Solution acquires stake in Sion Power
# 📌 Processing Article: Addionics plans to produce copper foils in the USA
# 📌 Processing Article: Group14 and SK Materials produce silicon-based anode material
# 📌 Processing Article: Northvolt commits to building its battery cell plant in Heide
# 📌 Processing Article: Stellantis likely planning another European battery factory without ACC
# 📌 Processing Article: AESC raises the stakes on BMW battery cell production in the USA
# 📌 Processing Article: Panasonic purchases synthetic graphite from Novonix
# 📌 Processing Article: PEM to support new battery coating process
# 📌 Processing Article: Epsilon Advanced Materials takes over battery centre in Germany
# 📌 Processing Article: GDI to produce silicon anodes in Germany
# 📌 Processing Article: ProLogium opens first factory for series production of solid-state cells
# 📌 Processing Article: SAIC-GM-Wuling presents battery pack for commercial vehicles
# 📌 Processing Article: Tata Group could separate from EV-related businesses
# 📌 Processing Article: Hyundai moves up the opening of its EV factory in Georgia to Q4 2024
# 📌 Processing Article: Fortum and Hydrovolt join forces on battery recycling
# 📌 Processing Article: Stardust Power to refine lithium in Oklahoma
# 📌 Processing Article: JSW Group to invest nearly $5 billion in EV projects in eastern India
# 📌 Processing Article: USSM secures fresh capital for recycling plant in the USA
# 📌 Processing Article: Siemens joins US start-up in optimising battery manufacturing at scale
# 📌 Processing Article: Tesla to build battery plant in Nevada with help from CATL
# 📌 Processing Article: Rimac ends cooperation with Camel Group
# 📌 Processing Article: OneD and Koch plan anode factory in North America
# 📌 Processing Article: VW enters into battery recycling cooperation for the UK
# 📌 Processing Article: US grants loans worth over $700 million for EV component plants
# 📌 Processing Article: Panasonic won’t be building batteries in Oklahoma
# 📌 Processing Article: Changan and Ganfeng team up for solid-state batteries
# 📌 Processing Article: Blackstone Technology will be dismantled
# 📌 Processing Article: BMW plans to build battery assembly in Thailand
# 📌 Processing Article: LGES procures more lithium from western Australia
# 📌 Processing Article: BASF and Stena join forces in recycling batteries
# 📌 Processing Article: US researchers increase energy density of sodium-ion batteries
# 📌 Processing Article: Primobius to build Mercedes’ battery recycling hub in Kuppenheim
# 📌 Processing Article: LionVolt wants to build cells for solid-state batteries in Scotland
# 📌 Processing Article: Verkor pulls in over €2 billion in fresh capital
# 📌 Processing Article: Germany: Straßkirchen residents cast clear vote for BMW’s new high-voltage battery assembly site
# 📌 Processing Article: Britishvolt owner Recharge faces legal action by staff
# 📌 Processing Article: SVOLT plans another battery plant outside China
# 📌 Processing Article: VW to launch high-voltage battery production in China
# 📌 Processing Article: Porsche may build batteries at Giga scale in Brandenburg
# 📌 Processing Article: Ford’s battery partners are also scaling back investments
# 📌 Processing Article: Altilium Metals receives £700,000 from UK government for two research projects
# 📌 Processing Article: TU Braunschweig inaugurates battery lab with focus on recycling
# 📌 Processing Article: SK On patents novel oxide-based solid electrolyte
# 📌 Processing Article: Stellantis builds another battery factory in the US
# 📌 Processing Article: Ghana’s first lithium mine to open in 2025
# 📌 Processing Article: Ascend Elements and SK ecoplant build battery recycling plant in the US
# 📌 Processing Article: Tesla to ramp up lithium refinery earlier than planned
# 📌 Processing Article: Verkor starts construction of battery cell factory in Dunkirk
# 📌 Processing Article: Gotion and InoBat outline key points for cell factory in Central Europe
# 📌 Processing Article: VW ready to break ground for Canadian battery plant
# 📌 Processing Article: EU approves nearly €660 mn in state aid for French battery firm Verkor
# 📌 Processing Article: GEL ready to extract lithium with geothermal process in Cornwall
# 📌 Processing Article: Germany approves bond for Northvolt factory in Heide
# 📌 Processing Article: BMW: Battery test centre in Wackersdorf opens in 2024
# 📌 Processing Article: £12 million to boost British battery material production through science
# 📌 Processing Article: Bosch plans recycling of fuel cell stacks
# 📌 Processing Article: Research into sodium-ion battery manufacturing processes
# 📌 Processing Article: Volvo Group purchases Proterra
# 📌 Processing Article: FEV opens battery cell lab in Aachen
# 📌 Processing Article: Toyota integrates recycled battery material from Redwood
# 📌 Processing Article: Chalmers University is developing a battery recycling process using oxalic acid
# 📌 Processing Article: USA: Daimler Truck, Paccar & Cummins to build LFP batteries
# 📌 Processing Article: BMW is building a battery competence centre in Leipzig
# 📌 Processing Article: Toyota orders cathode materials from LG Chem in the USA
# 📌 Processing Article: Enevate and NantG Power join forces on battery innovations
# 📌 Processing Article: Factorial Energy provides 100 Ah solid battery cell for testing
# 📌 Processing Article: Tobias Hüppe moves from Northvolt to Skeleton
# 📌 Processing Article: SAIC & ChingTao to launch solid-state battery joint venture
# 📌 Processing Article: KG Mobility to build battery factory in South Korea
# 📌 Processing Article: zepp.solutions to build fuel cell plant near Rotterdam
# 📌 Processing Article: Toyota & Cirba join forces for US battery recycling
# 📌 Processing Article: Ascend Elements closes funding round with over $500 million
# 📌 Processing Article: BASF & SK On announce battery cooperation
# 📌 Processing Article: Lithium mine to open in Ghana
# 📌 Processing Article: New Flyer buses to come with batteries by ABS next year
# 📌 Processing Article: Lyten raises $200 million in capital
# 📌 Processing Article: Gotion and InoBat planning battery factory in Slovakia
# 📌 Processing Article: CATL claims 1,000-km range for new skateboard platform in testing
# 📌 Processing Article: Scania kicks off its own battery assembly in Sweden
# 📌 Processing Article: Volvo Group to reutilise electric truck and bus batteries
# 📌 Processing Article: StoreDot & Flex-N-Gate announce cooperation
# 📌 Processing Article: Northvolt receives funding approval for battery plant in Heide
# 📌 Processing Article: LGES could build EV batteries with JSW in India
# 📌 Processing Article: Volvo has its eyes on StoreDot’s XFC cells
# 📌 Processing Article: LG Energy Solution is ramping up battery production capacities
# 📌 Processing Article: Renault may get battery cells made in Spain from China’s AESC
# 📌 Processing Article: New battery research centre to open in Ohio
# 📌 Processing Article: CATL and Fraunhofer IKTS predict batteries’ lifetime
# 📌 Processing Article: Andrada Group to build battery recycling plant in Hungary
# 📌 Processing Article: Battery recycler Redwood raises just over 1 billion dollars
# 📌 Processing Article: VW still hesitant about Eastern European battery factory
# 📌 Processing Article: GS Yuasa moves European headquarters to Swindon
# 📌 Processing Article: Circu Li-ion receives millions in seed funding
# 📌 Processing Article: CALB reveals high-density battery with 25-year lifecycle
# 📌 Processing Article: Fortum purchases metal shredder for recycling
# 📌 Processing Article: Battery recycling startup Cylib opens pilot plant
# 📌 Processing Article: BASF converts battery materials business into independent unit
# 📌 Processing Article: Ionway to build cathode plant in Poland
# 📌 Processing Article: Interview: Li-Cycle founder Tim Johnston on battery recycling in Europe
# 📌 Processing Article: Ford downgrades battery plans in the USA, cancels plant in Turkey
# 📌 Processing Article: PowerCo & Umicore’s joint venture opens for business
# 📌 Processing Article: Northvolt may prefer an IPO in Europe
# 📌 Processing Article: Northvolt to build battery factory in Quebec
# 📌 Processing Article: Northvolt raises further capital for Canadian factory
# 📌 Processing Article: Echion announces major investment from Volta Energy
# 📌 Processing Article: CNGR to build battery materials factory in Morocco
# 📌 Processing Article: EcoPro & Samsung SDI sign cathode materials deal worth over 30 billion euros
# 📌 Processing Article: Nio seeks investors for battery business
# 📌 Processing Article: Nissan commits to the UK with plans for 3 EVs and 3 battery factories
# 📌 Processing Article: BMW receives first solid-state cells from Solid Power
# 📌 Processing Article: Ionic MT prepares to produce silicon powder
# 📌 Processing Article: Gotion High-Tech launches battery production in Germany
# 📌 Processing Article: CATL finds two new customers for its Shenxing batteries
# 📌 Processing Article: Ola Electric closes funding round to build battery plant
# 📌 Processing Article: BASF & partners to localise battery supply chain in North America
# 📌 Processing Article: Eramet practices EV battery recycling
# 📌 Processing Article: Stellantis inaugurates recycling centre in Turin
# 📌 Processing Article: SVOLT rumoured to have signed battery supply deal with BMW
# 📌 Processing Article: Another sodium-ion battery factory is in the making in China for Zoolnasm
# 📌 Processing Article: Our Next Energy increases LPF battery pack energy density
# 📌 Processing Article: UK: Recyclus opens battery recycling factory, hoping to recover 22 tons a year by 2025
# 📌 Processing Article: BMW no longer builds combustion engines in Germany
# 📌 Processing Article: Ascend Elements develops cathode material for Freudenberg
# 📌 Processing Article: New CATL factory outputs one cell per second
# 📌 Processing Article: ABB to support Gotion High-Tech’s new battery factories
# 📌 Processing Article: Li-Cycle interrupts construction of US recycling plant
# 📌 Processing Article: Livista secures site in Germany for lithium refinery
# 📌 Processing Article: Volkswagen-backed 24M shows battery without cells and modules
# 📌 Processing Article: Groundbreaking ceremony for Eve Energy’s Hungarian battery factory
# 📌 Processing Article: ICPT and Solaris extend battery supply contract
# 📌 Processing Article: Exyte builds dry room in PowerCo battery factory Salzgitter
# 📌 Processing Article: ICPT sources modules from LGES for electric bus batteries
# 📌 Processing Article: BYD & Huaihai move on plans for sodium-ion battery plant
# 📌 Processing Article: BMZ to build battery factory in North Macedonia
# 📌 Processing Article: Tozero sources battery scrap from Huayou Cobalt
# 📌 Processing Article: Dräxlmaier opens high voltage battery assembly in Leipzig
# 📌 Processing Article: Toyota pours another 8 billion dollars into US battery production
# 📌 Processing Article: USA: Factorial Energy opens solid-state battery development and production site
# 📌 Processing Article: Umicore supplies cathode material for BMW’s US battery cells
# 📌 Processing Article: Epsilon Advanced Materials to build graphite anode factory in the US
# 📌 Processing Article: Fortum Battery Recycling develops pilot plant for new methods
# 📌 Processing Article: LG Chem and Huayou plan several battery material factories
# 📌 Processing Article: Northvolt presents its own sodium-ion battery cell
# 📌 Processing Article: UL Solutions opens battery testing lab in Korea
# 📌 Processing Article: China’s Gotion High-Tech takes 25% stake in InoBat
# 📌 Processing Article: Volvo and Northvolt start building battery cell factory in Gothenburg
# 📌 Processing Article: Hyundai places first battery cell order with Samsung SDI
# 📌 Processing Article: British battery firm Altilium to work with ABB on recycling plants
# 📌 Processing Article: Stellantis and Orano to recycle EV batteries
# 📌 Processing Article: Hyundai hitches to the nickel supply chain via Korea Zinc
# 📌 Processing Article: Mullen to produce battery packs in Fullerton, California
# 📌 Processing Article: Stellantis & Samsung SDI to build another cell factory in Indiana
# 📌 Processing Article: Toyota & Idemitsu announce solid-state battery development cooperation
# 📌 Processing Article: MiKoBatt: PEM, PowerCo and Jagenberg research cell production
# 📌 Processing Article: SAIC opens EV factory in Thailand
# 📌 Processing Article: Panasonic orders anode material from Sila Nanotechnologies
# 📌 Processing Article: Nio and SVOLT to jointly develop cylindrical cells
# 📌 Processing Article: CATL to produce fast-charging Shenxing battery in Europe
# 📌 Processing Article: Eramet and Suez build battery recycling plant in Dunkirk
# 📌 Processing Article: EIB grants AESC funds for battery factory in France
# 📌 Processing Article: Tozero opens pilot battery recycling plant
# 📌 Processing Article: Forge Nano to open battery cell plant in North Carolina
# 📌 Processing Article: Redwood Materials purchases Redux Recycling
# 📌 Processing Article: This is yet the smallest second-life for Nissan Leaf batteries
# 📌 Processing Article: New raw material partner for Nano One Materials
# 📌 Processing Article: Rimac to use Eve Energy cells in battery packs
# 📌 Processing Article: Gotion High-Tech opens battery plant in Thailand
# 📌 Processing Article: Will Mercedes’ electric vans get battery cells from AESC?
# 📌 Processing Article: Mahle opens test and development centre for batteries
# 📌 Processing Article: Siemens invests in Skeleton Technologies
# 📌 Processing Article: Gotion High-Tech to open cell plant in Illinois in 2024
# 📌 Processing Article: USA: Ford interrupts construction work on LFP cell factory
# 📌 Processing Article: Li-Cycle commissions German battery recycling plant – and announced its first partner
# 📌 Processing Article: Atos delivers IT for ACC battery factories
# 📌 Processing Article: Cell samples for BMW’s New Class roll off the assembly line
# 📌 Processing Article: Stellantis opens battery tech centre in Turin
# 📌 Processing Article: SungEel HiTech & Samsung plan battery recycling in Germany
# 📌 Processing Article: ICL is building an LFP battery plant in Missouri
# 📌 Processing Article: Nio delays plans for proprietary battery plant
# 📌 Processing Article: Lithion to set up battery recycling facility near Montreal
# 📌 Processing Article: Kore Power and Siemens cooperate for US cell factory
# 📌 Processing Article: Mercedes & CATL subsidiary Brunp announce battery recycling cooperation
# 📌 Processing Article: USA: LPO announces conditional loan for BlueOval SK
# 📌 Processing Article: Li-Cycle and Kion Group sign battery recycling agreement
# 📌 Processing Article: Eve Energy & Absolute Energy to build battery plant in Thailand
# 📌 Processing Article: Solid state battery company Factorial expands into Europe
# 📌 Processing Article: Ford to source nickel from Indonesia
# 📌 Processing Article: EU project ‘GIGABAT’ to analyze battery supply chains
# 📌 Processing Article: Plug Power offers modular hydrogen storage solution
# 📌 Processing Article: LG & Panasonic rumoured to supply Tesla’s 4680 battery cells
# 📌 Processing Article: Huayou Cobalt to build cathode plant in Hungary
# 📌 Processing Article: Northvolt & EMR open first recycling plant in Hamburg
# 📌 Processing Article: Tesla kicks off lithium refinery construction in Texas
# 📌 Processing Article: GM & Samsung SDI battery cell factory to be built in Indiana
# 📌 Processing Article: GM to install battery assembly at Ingersoll factory
# 📌 Processing Article: Panasonic to quadruple its battery production
# 📌 Processing Article: LGES Arizona battery factory will be larger than planned
# 📌 Processing Article: XTC New Energy Materials to build battery material factory in France
# 📌 Processing Article: Siemens to support Lishen to scale battery production
# 📌 Processing Article: PowerCo & Umicore receive regulatory approval for joint venture
# 📌 Processing Article: Judian builds solid-state battery factory in Ganzhou
# 📌 Processing Article: Tesla increases lithium order with Yahua Group
# 📌 Processing Article: Stellantis & Samsung SDI plan 2nd US battery plant
# 📌 Processing Article: Posco to build further battery materials plants with support from China
# 📌 Processing Article: StoreDot licenses XFC battery to VinES
# 📌 Processing Article: Altilium Metals and Marubeni sign non-binding MOU
# 📌 Processing Article: Valmet has Kuka install efficient battery assembly in Finland
# 📌 Processing Article: Reefilla & FPT launch 2nd life project with spent Iveco batteries
# 📌 Processing Article: Fortum to open battery recycling hub in Germany
# 📌 Processing Article: Tesla produces second 4680-cell generation in Texas
# 📌 Processing Article: Tata and AESC could prepare joint cell production
# 📌 Processing Article: Subaru to source cylindrical cells from Panasonic
# 📌 Processing Article: SK On to significantly expand battery plant in Seosan
# 📌 Processing Article: Ontario funds Li-Metal to develop lithium metal production technology
# 📌 Processing Article: Imerys & British Lithium prepare lithium mining in Cornwall
# 📌 Processing Article: Cellforce uses Siemens’ Xcelerator portfolio
# 📌 Processing Article: BASF inaugurates first cathode materials factory in Germany
# 📌 Processing Article: Basquevolt to produce first batteries before 2024
# 📌 Processing Article: Anovion to build battery material plant in Georgia
# 📌 Processing Article: Volkswagen may build its next battery factory in Indonesia
# 📌 Processing Article: Maersk to build battery logistics centre in Germany
# 📌 Processing Article: Northvolt and Volvo pave the way for cell factory in Gothenburg
# 📌 Processing Article: Tesla and CATL could build LFP plant in the US
# 📌 Processing Article: ElringKlinger scores major contract to outfit BMW Neue Klasse EVs
# 📌 Processing Article: SVOLT is setting up a battery assembly facility in Thailand
# 📌 Processing Article: Panasonic orders silicone anodes from Nexeon
# 📌 Processing Article: Lion Smart to source battery cells from SVOLT
# 📌 Processing Article: JLR to source battery cells from Agratas
# 📌 Processing Article: Finnish Minerals plans cathode materials production
# 📌 Processing Article: On this side of miracles: the five most important battery trends
# 📌 Processing Article: VW starts battery plant construction in Valencia and plans third party sales
# 📌 Processing Article: Northvolt recieves US $400 million from Canadian firm IMCO
# 📌 Processing Article: Finnish Minerals Group signs MoU on new plant
# 📌 Processing Article: Tevva cooperates with battery recycler Ecobat
# 📌 Processing Article: Samsung SDI opens new battery research centre in Shanghai
# 📌 Processing Article: BYD & Huaihai planning Na-ion battery factory in China
# 📌 Processing Article: Stena opens new battery recycling plant in Sweden
# 📌 Processing Article: BMW orders cell contacting systems from Molex
# 📌 Processing Article: General Motors invests in lithium mining company EnergyX
# 📌 Processing Article: Tata Group to build battery factory in Gujarat
# 📌 Processing Article: First machines arrive at German VW battery factory
# 📌 Processing Article: Entek to build separator factory in Indiana
# 📌 Processing Article: Fortescue announces new facility in UK
# 📌 Processing Article: Varta signs supply deal with SK Nexilis
# 📌 Processing Article: BMW’s cylindrical cells rumoured to be better than Tesla’s
# 📌 Processing Article: Lithium mining in Cornwall gets another push
# 📌 Processing Article: Stellantis buys into Li-S battery developer Lyten
# 📌 Processing Article: Cabot to build battery centre in Germany
# 📌 Processing Article: Coulomb to build US battery assembly facility
# 📌 Processing Article: Mahle & ProLogium to develop thermal management for solid-state batteries
# 📌 Processing Article: Eve Energy to build battery factory in Hungary
# 📌 Processing Article: SK On announces plan for precursors joint venture in South Korea
# 📌 Processing Article: CALB announces battery cell with improved density
# 📌 Processing Article: Renault ties the knot for Verkor battery cells
# 📌 Processing Article: Kore Power scores financial support from Washington
# 📌 Processing Article: Ascend Elements announces major battery material order
# 📌 Processing Article: Albemarle to build lithium refinery in South Carolina
# 📌 Processing Article: Ford, SK On, and EcoProBM build cathode factory in Canada
# 📌 Processing Article: Li-Cycle opens battery recycling plant in Germany
# 📌 Processing Article: Oak Ridge Lab to improve battery dry coating processes
# 📌 Processing Article: Mercedes lays foundation stone at battery recycling plant
# 📌 Processing Article: Sakuu aims to go public via merger with Plum
# 📌 Processing Article: Mercedes launches construction of InnoLab Battery in Mannheim
# 📌 Processing Article: VW may prefer US over Eastern Europe for battery cell factory
# 📌 Processing Article: CATL plans recycling sites in Europe and North America
# 📌 Processing Article: PowerCo to nearly double staff numbers
# 📌 Processing Article: Altilium Metals presents details of upcoming recycling plant
# 📌 Processing Article: Hyundai Mobis launches construction of battery plant in Indonesia
# 📌 Processing Article: ABTC to set up battery recycling facility in Nevada
# 📌 Processing Article: VW subsidiary PowerCo to build EV ecosystem in Indonesia
# 📌 Processing Article: VW invests 300 million euros in battery assembly at Seat
# 📌 Processing Article: SVOLT to build five battery cell plants in Europe
# 📌 Processing Article: Umicore builds solid-state battery prototypes in Belgium
# 📌 Processing Article: BYD invests in battery assembly plant in Hungary
# 📌 Processing Article: Li-Cycle & Eve Energy launch battery recycling collaboration
# 📌 Processing Article: Hyundai Mobis scores massive order from Volkswagen
# 📌 Processing Article: Panasonic postpones 4680 cell mass production by several months
# 📌 Processing Article: Group14 is taking over Schmid Silicon
# 📌 Processing Article: Leclanche reveals 6R concept & new ferry contracts
# 📌 Processing Article: BASF subsidiary and Advent Technologies set up European FC supply chain
# 📌 Processing Article: Fortum opens large-scale battery recycling plant in Finland
# 📌 Processing Article: Electra Battery Materials successfully completes battery recycling trial
# ...
# 📌 Processing Article: LG Chem to open second battery factory in China
# 📌 Processing Article: Volkswagen & Northvolt form European Battery Union
# 📌 Processing Article: Tesla in negotiation with CATL for battery cells
# 📌 Processing Article: VW & SK Innovation looking into battery manufacturing
# 📌 Processing Article: BMW double battery production capacity in Spartanburg, USA
# 📌 Processing Article: Battery production by CATL & Dongfeng JV kicks off
# 📌 Processing Article: SK Innovation to build first battery cell factory in USA
# 📌 Processing Article: Mercedes-Benz to build battery assembly plant in Poland
# 📌 Processing Article: Tesla working on closed-loop battery recycling
# 📌 Processing Article: EU fuel cell project INN-BALANCE making progress
# 📌 Processing Article: Tesla is hiring for Gigafactory 3 in China
# 📌 Processing Article: Voltabox takes over Navitas Systems
# 📌 Processing Article: Kamenz: A visit to Daimler’s battery assembly factory
# 📌 Processing Article: BYD and Panasonic looking to establish UK battery factory
# 📌 Processing Article: Johnson Matthey to build battery demo plant in UK
# 📌 Processing Article: Siemens to set up hydrogen centre in Görlitz
# 📌 Processing Article: Audi batteries storing energy in second-life setting
# 📌 Processing Article: Oxis prepares for serial production of Li-S batteries
# 📌 Processing Article: CATL revealing details on battery factory in Erfurt
# 📌 Processing Article: Battery cell production in Europe: a view from France
# 📌 Processing Article: Estonia’s Skeleton to invest €25M in supercap plant
# 📌 Processing Article: Six Consortia want to build battery cells in Germany
# 📌 Processing Article: Akasol to deliver heavy duty batteries to Sweden
# 📌 Processing Article: Leclanche & Exide form JV to make batteries for India
# 📌 Processing Article: BMZ & Kion found battery production joint venture
# 📌 Processing Article: Groundbreaking: E4V tripling battery assembly
# 📌 Processing Article: Sino-German project to validate FC motors
# 📌 Processing Article: Indonesia: International consortium seeks nickel & cobalt
# 📌 Processing Article: Blackstone invest €200M in European cell production
# 📌 Processing Article: Tesla in talks for additional Gigafactory
# 📌 Processing Article: VW turns to Northvolt for battery cell mass production
# 📌 Processing Article: Li-S battery specialist Oxis finds new investors
# 📌 Processing Article: Battery specialist Akasol plans new U.S. factory
# 📌 Processing Article: BMW to stop purchasing Congo cobalt in 2020/21
# 📌 Processing Article: Saft founds a battery cell JV in China
# 📌 Processing Article: Lishen may supply battery cells to Tesla in China
# 📌 Processing Article: Gigafactory: Musk says 35 GWh not yet achieved
# 📌 Processing Article: Dräxlmaier producing Porsche Taycan battery system
# 📌 Processing Article: Belectric lends life to thousands of electric car batteries
# 📌 Processing Article: Wanxiang to build 80 GWh battery factory
# 📌 Processing Article: VW bundles their battery business
# 📌 Processing Article: Malaysia may make energy-dense battery cells 18650
# 📌 Processing Article: Daimler starts building new battery sub-plant
# 📌 Processing Article: Panasonic planning to increase production capacities in Gigafactory
# 📌 Processing Article: Further rumours of Tesla’s own battery production
# 📌 Processing Article: Hyundai to produce its own electric car batteries?
# 📌 Processing Article: Volkswagen Board releases €1Bn for battery cell factory
# 📌 Processing Article: Daimler breaks ground for U.S. battery factory
# 📌 Processing Article: CATL catapulted to be worth billions on stock exchange
# 📌 Processing Article: VW secures solid-state technology from QuantumScape
# 📌 Processing Article: Akasol making better batteries for eCitaro by Daimler
# 📌 Processing Article: BYD looking to set up battery factory in Europe
# 📌 Processing Article: Tesla flies in battery production line from Grohmann
# 📌 Processing Article: Continental looking for solid state research partner
# 📌 Processing Article: Germany: Akasol to hit 800 MWh by early 2020
# 📌 Processing Article: LG Chem triples manufacturing capacities in Poland
# 📌 Processing Article: BMZ investing €120M in growing battery business
# 📌 Processing Article: Northvolt forges partnership for battery modules
# 📌 Processing Article: Berlin attempts to bring in Tesla factory
# 📌 Processing Article: BMW supplies i3 battery packs to Motiv Power Systems
# 📌 Processing Article: Germany: 3 battery consortia will be funded
# 📌 Processing Article: Audi sets up 1.9 MWh battery storage in Berlin
# 📌 Processing Article: Finland: Valmet plans large-scale battery production
# 📌 Processing Article: Enovate to cooperate with ProLogium on solid-state battery
# 📌 Processing Article: Poland: SK Innovation has construction plans for LiBS factory
# 📌 Processing Article: EIB gives first clearance for €350M loan for Northvolt
# 📌 Processing Article: Umicore to ramp up recycling of electric car batteries
# 📌 Processing Article: Hungary: SK Innovation to build second battery factory
# 📌 Processing Article: VW releases battery recycling details
# 📌 Processing Article: Germany ready to pour billions into battery cell production
# 📌 Processing Article: CATL moves into German battery factory early
# 📌 Processing Article: Fox plans to revive Mia electric car with Lion battery
# 📌 Processing Article: Umicore sets up cathode factory in Poland
# 📌 Processing Article: Nissan begins researching battery second life in Brazil
# 📌 Processing Article: LG Chem to supply batteries to Vietnam
# 📌 Processing Article: Swiss Ecovolta building 200 MWh Li-ion battery factory
# 📌 Processing Article: Hungary: SK Innovation starts construction of 2nd battery factory
# 📌 Processing Article: Farasis sets up production in China and EU
# 📌 Processing Article: Oxis Energy releases details re: Brazilian Li-S cell manufacture
# 📌 Processing Article: DE: Battery experts forge path from science to production
# 📌 Processing Article: CATL to begin German factory construction in 2019
# 📌 Processing Article: PSA, Opel and Saft battery consortium ready to go
# 📌 Processing Article: CATL boosts battery cell factory in Germany to 100GWh
# 📌 Processing Article: Korea’s first EV battery recycling centre on Jeju island
# 📌 Processing Article: First German battery cell factory taking shape
# 📌 Processing Article: CATL eyeing Europe for battery production
# 📌 Processing Article: India is planning at least four battery cell factories
# 📌 Processing Article: SK Innovation breaks ground on first cell factory in US
# 📌 Processing Article: Nissan scraps one billion dollar battery deal with GSR
# 📌 Processing Article: Hi-tech recycling of Li-ion batteries at Redux
# 📌 Processing Article: EU Battery Alliance accelerating progress
# 📌 Processing Article: Solid-state battery production begins in China
# 📌 Processing Article: BYD announces 20 GWh battery factory in Chongqing
# 📌 Processing Article: Tesla CEO favours Gigafactory in Germany
# 📌 Processing Article: Oxis Energy improves Li-S Battery energy density
# 📌 Processing Article: AVL List completes Battery Lab expansion in Graz
# 📌 Processing Article: LG opens new battery factory for Chevy Bolt
# 📌 Processing Article: BYD pushing to increase battery production capacity
# 📌 Processing Article: Tesla looking to implement Maxwell dry electrodes
# 📌 Processing Article: Siemens supporting Northvolt with Swedish “Gigafactory”
# 📌 Processing Article: Freudenberg buys majority of XALT Energy
# 📌 Processing Article: Cobalt now classed “strategic” substance in Congo
# 📌 Processing Article: Akasol has a new commercial vehicle battery
# 📌 Processing Article: Panasonic ahead of schedule for Gigafactory expansion
# 📌 Processing Article: Akasol opens battery production plant in Detroit
# 📌 Processing Article: Daimler orders €20BN worth of batteries
# 📌 Processing Article: Daimler doubles workforce at battery factory a year early
# 📌 Processing Article: Nissan sells battery business to Envision Group
# 📌 Processing Article: Korea: LG Chem is building a new cathode factory
# 📌 Processing Article: Volkswagen boosts stake in QuantumScape
# 📌 Processing Article: FirstElement gets funding to boost hydrogen capacities
# 📌 Processing Article: CATL to set up battery cell manufacturing in Germany
# 📌 Processing Article: CATL massively increases investment in Erfurt
# 📌 Processing Article: General Motors opens battery factory in China
# 📌 Processing Article: BMW secures CATL battery cells worth four billion euros
# 📌 Processing Article: Ceres building new fuel cell production facility in the UK
# 📌 Processing Article: Vattenfall power storage with 500 BMW i3 batteries goes live
# 📌 Processing Article: Panasonic to raise battery cell production in China by 80%
# 📌 Processing Article: Eastern Europe: InoBat and MOL prepare for hydrogen projects
# 📌 Processing Article: Hyundai goes full steam ahead on fuel cell systems
# 📌 Processing Article: BMW Brilliance expanding battery factory in China
# 📌 Processing Article: CATL to begin Erfurt battery factory construction by fall
# 📌 Processing Article: BMW localises battery production in Thailand
# 📌 Processing Article: VW sets up battery task force with LG Chem
# 📌 Processing Article: CATL & Panasonic profits drop due to investments
# 📌 Processing Article: GM and Honda to develop next gen batteries
# 📌 Processing Article: Ford cooperating with Solid Power on SS batteries
# 📌 Processing Article: Gigafactory 1 expansion on ice?
# 📌 Processing Article: SK Innovation to get bigger US battery cell factory
# 📌 Processing Article: BASF builds battery material factory in Finland
# 📌 Processing Article: Volvo Group signs up for batteries from CATL and LG Chem
# 📌 Processing Article: Fortum capable of 80% recycling on industrial scale
# 📌 Processing Article: Possible loophole? Geely to use LG batteries made in China
# 📌 Processing Article: Energy Absolute outlines plans for battery factory in Asia
# 📌 Processing Article: Webasto increases e-mobility engagement in Korea
# 📌 Processing Article: Cell production for Tesla Model 3 hits 11 GWh
# 📌 Processing Article: Farasis to locate battery plant in Saxony-Anhalt
# 📌 Processing Article: Myth busting: Battery recycling does work
# 📌 Processing Article: EU battery cell production: First funding in June
# 📌 Processing Article: Poland: LG Chem factory plans take shape
# 📌 Processing Article: Forsee Power to deliver e-scooter batteries to Niu
# 📌 Processing Article: BASF plans to lower nickel ratio in batteries
# 📌 Processing Article: BYD breaks ground for battery cell plant in Chongqing
# 📌 Processing Article: LG Chem and Geely form joint venture for batteries
# 📌 Processing Article: Volvo bus batteries find 2nd life as solar energy storage
# 📌 Processing Article: INN-BALANCE detailing novel fuel cell components
# 📌 Processing Article: BayBatt: University of Bayreuth established battery centre
# 📌 Processing Article: VW invests for 20% of Northvolt
# 📌 Processing Article: SVOLT presents cobalt-free Li-ion battery cell
# 📌 Processing Article: SK Innovation to build battery cell factory in China
# 📌 Processing Article: VW to support battery suppliers with production setup
# 📌 Processing Article: Northvolt wins permit for building Europe’s first Gigafactory
# 📌 Processing Article: BYD to more than double battery production by 2020
# 📌 Processing Article: China: Solar giant GCL wants EV makers in new ‘eco-town’
# 📌 Processing Article: Hyundai forges partnership for 2nd life batteries
# 📌 Processing Article: Battery maker Akasol aiming for growth through IPO
# 📌 Processing Article: Battery developer Nano One awarded contract from carmaker
# 📌 Processing Article: China: AESC builds 20 GWh battery cell plant
# 📌 Processing Article: Forsee Power expands electric bus battery portfolio
# 📌 Processing Article: SVOLT plans battery cell factory in Europe
# 📌 Processing Article: Battery cell production in Germany reforms
# 📌 Processing Article: Northvolt finds supplier for planned Gigafactory in Europe
# 📌 Processing Article: Germany: battery cell manufacturing incoming
# 📌 Processing Article: VW considering in-house battery cell production
# 📌 Processing Article: Northvolt begins construction of R&D center
# 📌 Processing Article: Sono Motors gives major battery contract to ElringKlinger
# 📌 Processing Article: GSR Capital invests in NEVS & building battery factory
# 📌 Processing Article: Bangkok becomes part of Daimler’s battery production hubs
# 📌 Processing Article: Northvolt has found Lithium supplier in Nemaska
# 📌 Processing Article: Akasol to deliver batteries for Daimler’s Citaro electric bus
# 📌 Processing Article: SK Innovation kicks off construction of Hungarian plant
# 📌 Processing Article: Webasto to focus on electric mobility solutions
# 📌 Processing Article: LG Chem to set up 2 battery material JVs with Huayou Cobalt
# 📌 Processing Article: Forsee Power to build electric bus batteries in France
# 📌 Processing Article: Musk: Next Gigafactory to be built in China
# 📌 Processing Article: A123 sells off battery factory to Lithium Werks
# 📌 Processing Article: Nissan opens recycling plant to swap EV batteries with 4R
# 📌 Processing Article: VW is bundling battery competencies in Germany
# 📌 Processing Article: MAN & Hamburg to give 2nd life to electric bus batteries
# 📌 Processing Article: China’s Lishen targets battery market in Europe
# 📌 Processing Article: Korea’s Shinheung SEC making batteries in Hungary
# 📌 Processing Article: Toyota to make batteries for hybrid cars in Thailand
# 📌 Processing Article: Volkswagen teams up with Samsung and LG Chem
# 📌 Processing Article: Panasonic producing prismatic batteries in China
# 📌 Processing Article: Toyota cuts exclusive lithium deal with Orocobre
# 📌 Processing Article: FEV extends battery test centre close to Paris
# 📌 Processing Article: Ionic Materials gathers $65m for solid-state battery technology
# 📌 Processing Article: BYD’s new battery plant to start producing this June
# 📌 Processing Article: Belgian Umicore raises over $1bn to grow cathode production
# 📌 Processing Article: Ultracap distribution sorted for Skeleton
# 📌 Processing Article: Volkswagen bets on batteries supplied by CATL
# 📌 Processing Article: Panasonic onboard with Tesla Gigafactory in China?
# 📌 Processing Article: Chile’s lithium resource redistributed through Corfo
# 📌 Processing Article: VW wants to increase its battery production fivefold
# 📌 Processing Article: French energy giant Engie invests in 2nd life batteries
# 📌 Processing Article: Tesla launches recruiting campaign for Gigafactory
# 📌 Processing Article: LG to augment capacities of its U.S. battery plant
# 📌 Processing Article: Belectric has built a battery storage facility for RWE
# 📌 Processing Article: Tesla loses senior battery engineer Ernest Villanueva
# 📌 Processing Article: Siemens may start producing batteries in Goerlitz
# 📌 Processing Article: Tennet uses 100 Tesla car batteries as buffer
# 📌 Processing Article: Daimler motor factory to turn into battery centre in Germany
# 📌 Processing Article: BASF and TODA reinforce battery production in Japan and USA
# 📌 Processing Article: Kick-off: Ballard’s FC systems get assembled in China
# 📌 Processing Article: Chinese Sokon group to erect battery plant
# 📌 Processing Article: CATL to build a Gigafactory – soon big enough to dwarf Tesla?
# 📌 Processing Article: EU sponsors 10 million euro open competition for battery technology
# 📌 Processing Article: Thyssenkrupp is expanding into eMobility markets
# 📌 Processing Article: A123 Systems invests in Ionic Materials for solid-state battery development
# 📌 Processing Article: Hi-tech stacking to make large-format Li-ion cells at ZSW
# 📌 Processing Article: Aalen University to research solid-state batteries
# 📌 Processing Article: Tesla may invest in Chile’s largest lithium producer
# 📌 Processing Article: Sweden backs Northvolt battery pilot plant with €15m
# 📌 Processing Article: Northvolt secures support from European Investment Bank
# 📌 Processing Article: Forsee Power to boost up battery production capacity
# 📌 Processing Article: BASF and Toda found cathode subsidiary in USA
# 📌 Processing Article: BYD tackles renewables – new battery strategy
# 📌 Processing Article: Mitsubishi Chemical expands production capacities
